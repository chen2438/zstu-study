# %% [markdown]
# # Python考试题
# ## 说明
# - 所有考试题都是开放的，也就是说，并没有标准答案，你的得分完全是根据你<font color=red>**最终的方法、努力的过程、提交的程序和报告**</font>来决定。
# - 题号后面的★代表了题目的难度，最低★，最高★★★★★，最终得分会考虑题的难度。
# - 如果对应的题目有数据文件，则以题号相同名称的文件都为该题的数据文件，例：4.png，4.rar都是4号题的数据文件。
# - <font color=red>**每一题只能一个小组做，所以注册前，请务必确认该题没有被占用，并截图发到Python通知群**。</font>
# - <font color=red>**注册必须以小组注册，至少3人，不多于5人，否则注册无效**。</font>
# - 既然是由小组团队完成，你们的报告应该尽可能详细地描述你们的思想、工作内容和技术路线，并评价你们的最终结果。简单地讲，就是你们做了什么，怎么做的，结果如何。
# - 希望你们的答辩选手能够很好地掌握你们做的内容，做得好，还要说得好。<br>
#
# **答辩事项：**
# 1. 答辩顺序为出题顺序；
# 2. 答辩时间考虑到考试周的情况，会视情况定日期，在学期结束前全部结束；
# 3. 答辩人在答辩前随机抽签决定；
# 4. 提交内容：notebook文件和pdf文件（notebook文件的打印稿，以学期开始时发的表格为首页）各一份，包括：
#   - 必备信息：题目，团队名称，团队组成人员名单（包含学号）；
#   - 技术思路和解决方案（包含代码）；
#  - 运行结果；
#  - 自我评价，哪些地方做得好，哪些不行，要改进。
#  - 文件内容要求图文并茂。
# 5. 成绩评定：以最终答辩和提交的报告作为评价依据，给答辩人评分，<font color=red>**小组总分为答辩人评分乘以小组人数，各成员的分数按学期最初制定的规则在小组内自行分配**</font>。
#
#
#
# ##  <font color=red>**以下内容不允许编辑**。</font>
# 1	py神小组：陈鑫波，徐鑫彪，陈泓甫，陈仲欢，陈可行<br>
# 2	爪巴组：郑略熙、赵耀、郑吉、周康彪<br>
# 3	TomJerry:王玮斌，于江雄，翟壮壮<br>
# 4	抢地组：高鑫，甘金彪，郭嘉鹏<br>
# 5	python小组：董丽媛，程雪艳，周星宇，程琰婕<br>
# 6	兰州拉面组：卢伟、潘圣盐、孟家炜、马玮峰、聂剑刚<br>
# 7	早睡早起选手 :杨焰琪 衣文静 喻梦甜 张耀东<br>
# 8	PY森组 林帅 林越盛 楼崇<br>
# 9	刚好一桌麻将小组：张文韬 刘颜铭 鲍晨翔 王旭<br>
# 10	随便整组：漆啸哲、沈光玮、沈天峰、沈哲远、施育铭<br>
# 11	逍遥门：侯德渠 陈英健 李瀚洋<br>
# 12	我们组太南了，组员：李逸飞、方超、曹旭涛<br>
# 13	678小分队 组员：林俊 陈涵龙 余柔刚 胡思琦 杨岚<br>
# 14	蒂花之秀组：林开雄、林宏纲、陈骏虎<br>
# 15	莫木白组：白睿，木德者，莫春豪<br>
# 16	刘关张：刘雍流，张博，张福群<br>
# 17  cnpy小组：丁观峰，邓志勇，程启超，丁乾龙<br>
# 18  初学者请多多见谅组：郑佳明 章路佳 朱博伦 周云挺<br>
# 19  套餐小组：庞凤铃，朴文甲，尹相媛<br>
# 20  菜鸡互啄: 阚兴成,林苗镔,邢文松,袁铎<br>
# 21  QAQ组：陈辉 陈哲 应恩挺<br>
# 22  咙咚呛组：蒋甜甜 陈瑶瑶 梅淑恩<br>
# 23  神無月 成员：杨友森，熊纪元，薛逸，严丹磊<br>
# 24  鸡米花 组员：徐家劲 赵森岗 陈新洲 吴康惠 黄柯<br>
# 25  haha组：黄吉昊 周振伟 邱芷晴<br>
# 26  我们来py交易组：胡裕康 陈焕 孙洪恩 郑钰东 王鹤荣<br>
# 27  114组：张可昀，沈思羽，王小红<br>
# 28  沙雕大冒险：余帆 吴思月 赵豪豪 崔云磊<br>
# 29  懒得取名小组：葛宇航 沈宇帆 邱锐鹏<br>
# 30  PY组：黄业霆、樊泽荣、刘星原、张宇路、金奇<br>
# 31  王老板：黄钰森，吴若渊，王西缘，孙瑶，周子瑜<br>
# 32  七角山组：吴晗 吴俊毅 王金辉<br>
# 33  爆肝996组：孙蒙达 祁炳灿 刘鑫<br>
# 34  午饭就吃黄焖鸡吧：包晨磊 舒航 宋翼<br>
# 35  py作业1号小分队：徐伟宁 申屠志刚 李佳珂 曾子胤 张满为<br>
# 36  <br>
# 37  <br>
# 38  <br>
# 39  <br>
# 40  <br>
# 41  <br>
# 42 <br>
# 43 <br>

# %% [markdown]
# ## 1.国之重器★★★★
# <img src='1.gif'>
#
# - 2019年10月1日，国庆盛大的阅兵式上，DF-41作为压轴的武器亮相。作为国之重器，DF-41有非常强悍的性能。
# - DF-41射程在12000千米以上。
# - 由于DF-41可以公路机动，请你以国内任何一点为起点，在地图上显示DF-41可攻击的范围。
# - 注意：这个范围要考虑弹道导弹的的运行特点，比如会先进入太空，然后再进入大气层等。

# %% [markdown]
# ## 2.地域分界★★★★
# <img src='./胡焕庸线.png' width=400, height=380>
#
# - 请你在地图上画出如下分界线：
# - 400mm降水线；
# - 胡焕庸线；
# - 汉长城，明长城；
# - 汉，唐，明疆域。
# - 请你自己想法获取数据，探讨它们之间与我国古代民族之间的关系。

# %% [markdown]
# ## 3.拓★★★★
# 小时候都玩过这样的游戏，把纸放在一个凹凸不平东西上，用铅笔划就可以在纸上出现这个东西的轮廓，这个操作就叫拓。<br>
# <img src='rubbings.jpg' width=180><br>
# 那么如果是一个点阵图像呢？能不能把图像里面的轮廓也用类似的思想把它提取出来，就像下面这样？<br>
# <img src='edge_detection.jpg' width=240><br>
# 请给出你的方案，关键是看效果。<br>

# %% [markdown]
# ## 4.腾讯视频★★★★
# 腾讯视频很多视频为了保护起见，都把它们分割成很小的一段，每一段地址都不相同，然后浏览器运行的js脚本不断向服务器请求数据，实现在浏览器端的流畅播放。<br>
# 现在，请你能否做一个嗅探+整合器，能够嗅控到这些视频段的地址，把它们下载下来，再拼合成一个完整的视频。<br>
# <font color=red>注意，我们只是为了研究技术，不是为了盗版！</color>

# %% [markdown]
# ## 5.热搜★★★★
# 新闻是有周期性的，一段时间以后，它的热度就会下降了。但不同的新闻，热度的持续时间会大不相同。<br>
# 请你找若干个新闻，看看它的热度的变化情况，然后总结一下，热度变化的原因。<br>
# 为什么要做这个？<br>
# 因为我们要有科技的方法来知道舆论的变化情况，并能够主导舆论。<br>

# %% [markdown]
# ## 6.键盘侠★★★★★
# 侠以武犯禁，这也是为什么历史上很多朝代对“侠”进行打击或限制的原因。<br>
# 现在很多人在网络上以“侠”自居，人称“键盘侠”。<br>
# 现在请你以若干个热门的新闻事件为例，看看目前网络上键盘侠的数量，并评价他们的行为。
# 你应该能够做到以下几点：
# - 你要确定什么是“键盘侠”？
# - 再来评价他们的行为。

# %% [markdown]
# ## 7.标准关联性★★★★★
# 我国的标准按大类，可以分为：国家标准，地方标准，行业标准，团体标准和企业标准等。<br>
# 目前我们国家标准数量已经非常庞大，这就造成新产生的标准与已有标准之间的重复性就会大大增加。<br>
# 现在请你来协助解决这个问题，就是对已有的标准，他们的内容和相互之间引用、参考关系，进行研究。
# 你可以从以下几个角度来考虑他们之间的联系：
# - 标准的名称；
# - 标准内容有专门的一节，是规范性引用文件，一般是引用其他的标准。
# 注意：有可能你能够下载到的标准不是文本的，你怎么识别里面的文字？你要好好考虑。

# %% [markdown]
# ## 8.另类的数据传输★★★★
# - 用网络的数据传输很常见，现在请你设计一个不常见的数据传输。
# - 请你用Python写一个程序，这个程序运行在两台笔记本上，实现两台笔记本之间的数据传输。
# - 但是，这个数据传输是有条件的，不允许使用有线、无线网络，如Lan、WiFi、Buletooth、2.4G、GSM、3G、4G、5G等，都是不允许的，当然，通过USB建立所谓的串行连接，用1394或其他的总线建立连接也是不允许的。
# - 总之，在数据传输时，我会检验笔记本的所有连接，都应处于Disable状态。
# - 如果你成功了，恭喜你，不过，还没完，你还要评估这个连接的数据传输速率，看看你能够达到多少，这个可以通过传输一个1M的文件来测试。
# - 这道题是去年做过的，不过，他们完成的情况不是非常好，所以，希望你能够给出一个完美的解决方案。

# %% [markdown]
# ## 9.通讯基本靠吼★★★★★
# 有一个笑话，说是有一个地方穷，“通讯基本靠吼”。<br>
# 但在特定的情况下，声音真的还是信息传输的唯一手段。<br>
# 现在，请你构造一个声音传输的方案，和第8题一样，不允许使用任何网络、USB等连接方式。<br>
# 另外，由于本题的存在，第8题不能采用本题的解决方案。

# %% [markdown]
# ## 10.大数据处理★★★★
# 大数据处理的一个典型方法是MapReduce。<br>
# 说得简单一点，就是因为数据量太大，一台计算机干不了，就多台计算机一起干。<br>
# 10.rar是一系列播放记录，因为加过密了，现在我们要把解密，数据量有点大。<br>
# 现在，请你使用MapReduce的思想，把它进行解密，解密以后，再进一步处理放入数据库。<br>
# 对比一下，使用单机和多机处理的时间。<br>
# 本题要用到des解密的库及单机解决的方式，参考：http://note.youdao.com/noteshare?id=7ee1d7665b2df67c03d01f071399df17&sub=4A28EFEEA3BA4A22BD1913A556275007

# %% [markdown]
# ## 11.ATA Password★★★★
# 一般人不知道硬盘也可以设置密码，那我现在告诉你，这可以。<br>
# 这个密码一般称为ATA密码，现在请你编写一个程序，能够读取或设置硬盘密码。<br>

# %% [markdown]
# ## 12.核分★★★★★
# 每次老师批改试卷，计分总是一个麻烦事情。<br>
# 现在请你用AI来解决这个问题。<br>
# 设计一个方案，能够大大减轻老师核分的工作量。<br>
# 你可以参考CNN进行邮政编码手写体识别的例子。
# <img src="recongnition.jpg" width="320" height="240">

# %% [markdown]
# # 13.进程编辑器★★★★
# 现在请你写一个Windows进程编辑器，它具有如下功能：
#  1. 能够列举目前所有的正在运行的进程；
#  2. 能够找到Windows程序窗体的句柄，然后判断这个窗体的类型，对这个窗体进行相关的操作：包括最大/最小化，输入文字，显示/隐藏等，获取窗体的文本等；
#  3. 能够对整个进程进行操作，如关闭。
# 当然，它需要有个界面。

# %% [markdown]
# # 14.3D打印★★★★★
# 3D打印说白了，就是将一个三维物体，在逻辑上切成一个个与XOY平面平行的薄片，然后驱动打印机从低到高打印一个个薄片，这样堆积起来就成了这个三维物体。<br>
# 现在，请你用Python来展示这个过程：<br>
#  1. 对空间中若干个点，求它们的闭包；
#  2. 然后就是求一个个的薄片了。
# 当然，希望你能够在计算机上把这个过程展现出来。

# %% [markdown]
# # 15.角钢塔套料★★★★★
# 看到过输电的角钢塔吗？就是下面这个图。<br>
# <img src='th.jpg' width=120 height=120><br>
# 角钢塔是用不同长度的角钢构建起来的，它的特点一种类型的角钢塔是基本上所使用的角钢材质是一样的，这样能够保证材料统一。<br>
# 现在，假定有长度为10米、15米和20米的角钢若干，需要切成不同的可用于构建铁塔的角钢（称为零件）材料长度，假定不考虑切割时材料的损耗，请你设计切割的策略，要求：
#  1. 材料的利用率尽可能高，也就是(零件总长/材料总长)*100%尽可能大；
#  2. 在保证1的情况下，材料的支数尽可能少。
# 先说明：如果仅仅是贪心的解决方案，你分数不会太高。
# nest.csv是测试数据。

# %% [markdown]
# # 16.民主★★★★★
# 民主到底是什么？或者说民主是目的，还是手段，一直饱受争议。<br>
# 但有一点明确的是，即使中国在民主领域取得了巨大的进步，让14亿享受到了社会主义民主，西方国家还是竭力诋毁。<br>
# 不过，民主还是值得研究的。现在请你想办法模拟一个Cyber空间的民主。<br>
#  1. 能够模拟像选举这样的情况；
#  2. 然后需要对这个民主模型进行一个客观的判断；
#  3. 如果能够用它来对比现实世界的民主，那就更好了。

# %% [markdown]
# # 17.老龄化★★★★
# 老龄化好像是现在各个国家都必须面对的一个问题，尤其是日本。日本已经连续10年人口下降。<br>
# 现在，需要你使用Python来对日本的人口进行一下预测，如果按这个方式发展下去，日本的人口趋势会是怎么样一个情况。<br>
# 要求：
#  1. 需要使用可视化的方式来展示你的结果；
#  2. 对你的结论，应该有较多的论据来支撑。

# %% [markdown]
# # 18.马六甲★★★★
# 为什么马六甲是咽喉要地，这个需要你用一个可视化的手段来说明。<br>
# 现在的问题是，如果中国真的和泰国合作，打通了克拉运河，或者由于中巴铁路贯通，马六甲会有大的影响吗？<br>
# 要点：一是要有充分面准确的数据，二是要能清晰地展示。

# %% [markdown]
# # 19.光照★★★★
# 万物生长靠太阳，现在请你考查一下我们国家的光照，这对我国的国民经济，特别是农业有着巨大的影响。<br>
# 由于数据的限制，现在只需要你建立7天的数据模型。<br>
# 数据来源，可以访问这里：http://data.cma.cn/Market/Detail/code/RADI_CHN_MUL_HOR/type/0.html<br>
# 从这个7天的数据模型，你可以得到什么结论。

# %% [markdown]
# # 20.陪伴老人★★★★
# 老人有时候很寂寞，你可以陪陪他们吗？<br>
# 可是你也很忙，那么可以请一个机器人来帮助他们吗？<br>
# 至少可以陪陪他们聊聊天吧<br>
# 请你做一个聊天机器人，不过，要注意的是，老人可能不太会打字了。

# %% [markdown]
# # 21.手谈★★★★
# 围棋又称手谈，现在请你评估一下，Facebook的围棋程序和腾讯的围棋程序哪个更厉害？<br>
# <img src='21.jpg' width=240 height=120><br>
# Facebook开源了ELF OpenGo，腾讯开源了PhoenixGo，你可以在以下网址找到他们。<br>
# https://github.com/pytorch/ELF<br>
# https://github.com/Tencent/PhoenixGo<br>
# 部署他们是第一步，让他们能够谈起来才行。

# %% [markdown]
# # 22.Shell★★★★
# shell 是一个用 C 语言编写的程序，它是用户使用 Linux 的桥梁。Shell 既是一种命令语言，又是一种程序设计语言。<br>
# Shell 是指一种应用程序，这个应用程序提供了一个界面，用户通过这个界面访问操作系统内核的服务。<br>
# Ken Thompson 的 sh 是第一种 Unix Shell，Windows Explorer 是一个典型的图形界面 Shell。<br>
# 现在，让你实现一个Windows的命令行Shell，参考一下cmd。你的成绩，与这个Shell的功能息息相关。<br>
# 希望你获得好成绩！<br>

# %% [markdown]
# # 23.民以食为天★★★★
# 知道丁戊奇荒吗？丁戊奇荒是一次旱灾饥荒，指19世纪70年代中后期，即1877—1878 年发生在中国大地的特大灾荒。<br>
# 你可以详细地去了解一下这段历史。<br>
# <center><img src='23.jpg' width='320'></center><br>
# 现在，请你去归纳和总结一下世界粮食价格和世界饥饿指数，看看他们之间有什么关系？<br>
# 从这个角度，请你用数据和图表来分析，为什么中国要坚守18亿亩耕地红线。<br>
# 因为我们不希望再次出现一次丁戊奇荒。

# %% [markdown]
# # 24.公正的判决★★★★★
# 中国不是一个判例法国家，但判例仍然具有非常高的参考意义。<br>
# 基本上所有的法律判决都可以在中国裁判文书网上找到。<br>
# 如果小明与其他人发生纠纷，需要进行诉讼，你是否可以帮他找到与他类似的法律案件？<br>
# 而且，能否自动对这些案件的判决与小明纠纷的相关性进行分析和判断呢？<br>
# 计算机改造了各行业，AI是不是可以推动各行业呢？<br>
# 律师下不下岗，该看你的了。

# %% [markdown]
# # 25.除螨★★★★
# 螨虫被认为是已知最强烈的过敏源。
# 它们几乎无处不在，甚至每夜成群结队地与人们同床而眠。
# 在“三月不晒被，百万螨虫陪你睡”的恐惧中，商家纷纷推出高科技除螨神器。
# 人们心想各种昂贵的除螨仪总能把螨虫除干净吧，但其实反而深陷除螨骗局当中<br>
# <img src='25.gif' width=320><br>
# 超声波让螨虫疯狂致死。除螨仪主要是利用超声波的作用于螨虫，螨虫置身于超声环境后会十分不安和痛苦，生理系统开始紊乱，食欲不振，迅速逃离原寄生处或逐渐死亡，最终使环境中的螨虫浓度降低，大幅减轻或消除患者的过敏症状。<br>
# 现在请你使用Python来试着让你的笔记本发出超声波，来除螨。如果你的程序真的做到了，希望可以成为你人生的第一桶金。

# %% [markdown]
# # 26.P=NP? 世界难题★★★★
# 世界七大难题分别是：NP完全问题、霍奇猜想、庞加莱猜想、黎曼假设、杨-米尔斯存在性和质量缺口、纳卫尔-斯托可方程、BSD猜想。<br>
# 按这个排序，第一个就是我们计算机的。<br>
# 这一问题的一个重大进展就是在70年代初由Stephen Cook和Leonid Levin给出，他们证明NP问题中的某些问题复杂性与整个NP问题类的复杂性关联，这些问题中任意一个如果存在多项式时间解法，那么NP=P。这些问题称为NP完全问题。<br>
# 到今天，科学家们已经发现了非常多的NP完全问题。<br>
# 现在，希望你能够对它们做一个总结：<br>
# 1. 尽可能多地列举NP完全问题；
# 2. 给出这些NP完全问题之间的证明链，例如：3SAT可归约到CLIQUE，因为3SAT是NP完全的，所以CLIQUE是NP完全的，那么你就用3SAT$\rightarrow $CLIQUE来表示它。
# 3. 最好能够给出这些NP完全问题之间完全的证明链图。

# %% [markdown]
# # 27.铁公鸡★★★
# 请你对比中国股市现金分红的企业，和纽约证交所（或纳斯达克）现金分红的企业，对比一下，哪些企业是铁公鸡。<br>
# 然后，考虑有什么方法，可以拔下铁公鸡的毛。

# %% [markdown]
# # 28.颜色革命★★★★
# “颜色革命”是指21世纪初期，在前苏联和中东北非地区发生的以颜色命名，以和平的非暴力方式进行的政权更迭运动。<br>
# 生产颜色革命的原因多种多样，但任何革命都一定有一个高尚的口号。<br>
# 请你获取发生颜色革命的国家，在颜色革命前和后，各项数据（如经济、教育水平、科技等）对比，来客观的看一下，颜色革命是不是真的如其高尚口号所说。<br>
# 当然，对数据的分析和分析结果是至关重要的。

# %% [markdown]
# # 29.空中高铁★★★
# <img src='29.jpg' width=320><br>
# 我们是技术人，应该用数据说话，请你客观地分析上述论点。<br>
# 注意：要有理有据。

# %% [markdown]
# # 30.洋垃圾★★★
# 中国一度是世界上最大的洋垃圾进口国家。<br>
# 现在请你根据数据分析，在一定时期内，包括现在，世界垃圾的产生的情况，去向的情况。<br>
# 然后将这些数据，以可视化图表的形式，结合你的分析，说明中国为什么于2017年年底生效垃圾进口禁令。<br>

# %% [markdown]
# # 31.美元指数★★★
# 现在的世界，军事已经不是霸权的第一选择。<br>
# 金融是更为有效和隐蔽的手段。<br>
# <img src=30.jpg width=320> <br>
# 我们今天就来看看美元，美元在几十年间，呈现出一种非常规律的形式。<br>
# 现在请你用数据来解析这种现象，然后再分析一下，近年来，这种规律是在加强，还是在减弱？为什么？<br>

# %% [markdown]
# # 32.商品价格★★★
# 想办法获取全球各个国家的电商的商品价格，然后以图表的形式，尽可能用简单地把这些价格信息表示出来。<br>
# 然后，分析这些价格背后隐藏的原因，原因肯定是多方面的，如果能够分清主次，那就很好了。<br>
# 单纯地比较一个商品并不一定能够说明问题，建议分成若干来类别来进行。<br>

# %% [markdown]
# # 33.天下无贼★★★
# 网络诈骗：通常指为达到某种目的在网络上以各种形式向他人骗取财物的诈骗手段。犯罪的主要行为、环节发生在互联网上的，用虚构事实或者隐瞒真相的方法，骗取数额较大的公私财物的行为。<br>
# 以上是百度百科的说法，但现在，可以认为只要在诈骗过程中，利用了电信网络、互联网等信息网络作为作案、销赃等手段的诈骗行为，都可以认为是网络诈骗。<br>
# 现在网络诈骗案件高发，希望用这道题来给大家敲响警钟。<br>
# 请你用数据来对近年来网络诈骗案件进行一个全面的阐述，内容可以包括如下几个方面：
# 1. 案件的类型：信用卡诈骗，假咨询信息，网上拍卖等；
# 2. 案件发生地的情况；
# 3. 受骗金额的情况；
# 4. 破案率的情况；
# 5. 其他你们认为可以总结或分类的。
#
# 希望天下无贼。

# %% [markdown]
# # 34.高性能网络★★★★★
# TCP/IP诞生之初，就不是为了高速数据传输为目的的。<br>
# 现在，假定有很大量的数据要从计算机A传输到计算机B，你能设计一个比TCP/IP更为快速的方案吗？<br>
# 如果要通过一台交换机呢？<br>
# 注意：你的方案必须是在同等的硬件条件下与TCP/IP比较。

# %% [markdown]
# # 35.人脸识别★★★★★
# 请你构造一个识别自己班上同学的人脸识别系统，如果能够用它来作为这次考试签到，那你就能够得到很好的成绩。<br>
# 希望你成功。

# %% [markdown]
# # 36.医疗问题★★★
# 最近的民航总医院行杨医生离世让医患关系又成为热点。<br>
# 诚然，目前的医疗状况的确不能让很多人满意，但另一方面，医生们的超负荷工作也是事实。<br>
# 我们必须对此有一个客观的认识。<br>
# 请你搜索相关数据，可以包括：医疗费用，治疗时间，治愈率等等，客观地来分析和对比我国的医疗水平与世界水平，然后给出你的结论。
