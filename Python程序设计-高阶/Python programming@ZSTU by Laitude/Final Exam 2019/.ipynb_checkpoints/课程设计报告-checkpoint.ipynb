# %% [markdown]
# # Python 课程设计
# ### 序号：2
# ### 题目：地域分界★★★★
# ### 组名：爪巴组
# ### 组员：2017329621181 郑略熙、2017329621178 郑吉、2017329621183 周康彪、2017329621176 赵耀

# %% [markdown]
# ## 1 引言

# %% [markdown]
# &emsp;&emsp;如今，Python已经成为一种再主流不过的编程语言了。它天生丽质，易于读写，非常实用，从而赢得广泛的群众基础，被誉为“宇宙最好的编程语言”，被无数程序员热烈追捧。随着时代的发展越来越快，市场需求越来越大，Python的应用也越来越广泛。

# %% [markdown]
# &emsp;&emsp;Python作为一门强大、跨平台、开源、免费的解释型高级动态编程语言，可以说是目前最易入门的语言了，且其有着自动化脚本的前身,语言有着很高的执行效率。应用Python中的库可以方便的完成大量复杂工作。本次课程设计就是利用Python强大的库实现地域分界——在地图上画出一段或一片区域。

# %% [markdown]
# ### 1.1 选题
# #### 本次我们小组选择的是2号题目——地域分界

# %% [markdown]
# ## 2 需求分析
# #### 本次课程设计需要我们在地图上画出以下几种分界线：

# %% [markdown]
# ### 2.1 400mm降水线

# %% [markdown]
# &emsp;&emsp;400毫米等降水量线，是我国一条重要的地理分界线，它大致经过：大兴安岭—张家口—兰州—拉萨—喜马拉雅山脉东部。主要是半湿润与半干旱区分界线。沿大兴安岭—张家口—兰州—拉萨—喜马拉雅山东南端一线，它同时也是我国的半湿润和半干旱区的分界线。是森林植被与草原植被的分界线。

# %% [markdown]
# ![400mm%E9%99%8D%E6%B0%B4%E7%BA%BF.jpg](attachment:400mm%E9%99%8D%E6%B0%B4%E7%BA%BF.jpg)

# %% [markdown]
# ### 2.2 胡焕庸线

# %% [markdown]
# &emsp;&emsp;胡焕庸线，即中国地理学家胡焕庸在1935年提出的划分我国人口密度的对比线，最初称“瑷珲—腾冲一线”，后因地名变迁，先后改称“爱辉—腾冲一线”、“黑河—腾冲一线”。

# %% [markdown]
# ![%E8%83%A1%E7%84%95%E5%BA%B8%E7%BA%BF.jpg](attachment:%E8%83%A1%E7%84%95%E5%BA%B8%E7%BA%BF.jpg)

# %% [markdown]
# ### 2.3 汉长城

# %% [markdown]
# &emsp;&emsp;汉长城又称外长城。安西境内现存汉长城150公里，烽燧70座，城障3处。东起玉门蘑菇滩，沿甘新公路南侧，疏勒河北岸，逶迤向西，与敦煌境内的西碱墩相连。这些汉长城及沿线的城障烽燧，是汉代河西完整的军事防御体系的重要组成部分，也是西汉王朝构建河西乃至整个北方防御工程的历史缩影。虽经千百年来的风雨剥蚀，仍然巍然屹立在戈壁荒漠中，堪称中国保存最为完好的汉长城之一。

# %% [markdown]
# ![%E6%B1%89%E9%95%BF%E5%9F%8E.JPG](attachment:%E6%B1%89%E9%95%BF%E5%9F%8E.JPG)

# %% [markdown]
# ### 2.4 明长城

# %% [markdown]
# &emsp;&emsp;明长城是明朝在北部地区修筑的军事防御工程，亦称边墙，明长城用材与秦长城相似，而区别于汉长城、清长城。其东起鸭绿江畔辽宁虎山，西至居庸关，另修建祁连山东麓到甘肃嘉峪关。其中，人工墙体的长度为六千二百五十九点六公里；壕堑长度为三百五十九点七公里；天然险长度为二千二百三十二点四公里。东部险要地段的城墙，用条石和青砖砌成,十分坚固。明长城东起鸭绿江，连接秦长城，然后西至嘉峪关，蜿蜒六千余公里，气势宏伟，是当时世界上的一个奇迹。

# %% [markdown]
# ![%E6%98%8E%E9%95%BF%E5%9F%8E.jpg](attachment:%E6%98%8E%E9%95%BF%E5%9F%8E.jpg)

# %% [markdown]
# ### 2.5 汉疆域

# %% [markdown]
# ![%E6%B1%89%E7%96%86%E5%9F%9F.jpg](attachment:%E6%B1%89%E7%96%86%E5%9F%9F.jpg)

# %% [markdown]
# ### 2.6 唐疆域

# %% [markdown]
# ![%E5%94%90%E7%96%86%E5%9F%9F.JPG](attachment:%E5%94%90%E7%96%86%E5%9F%9F.JPG)

# %% [markdown]
# ### 2.7 明疆域

# %% [markdown]
# ![%E6%98%8E%E7%96%86%E5%9F%9F.jpg](attachment:%E6%98%8E%E7%96%86%E5%9F%9F.jpg)

# %% [markdown]
# ### 2.8 他们与古代民族的关系

# %% [markdown]
# &emsp;&emsp;在这简单介绍一下400mm等降水线、胡焕庸线、汉明长城、汉唐明疆域与我们古代民族的关系，详细的介绍在4.8给出。

# %% [markdown]
# &emsp;&emsp;**400毫米等降水量线，是我国一条重要的地理分界线**，它大致经过：大兴安岭—张家口—兰州—拉萨—喜马拉雅山脉东部。主要是半湿润与半干旱区分界线。是半湿润区与半干旱区的分界线。是种植业与畜牧业分界线。是农耕文明与游牧文明的分界线。是西北地区与北方地区分界线。400mm降水量线把我国大致分为东南与西北两大半壁。400毫米等降水量线是我国季风区与非季风区的划分界线。

# %% [markdown]
# &emsp;&emsp;元朔年间，匈奴不断入辽西、上谷、渔阳杀掠吏民，武帝命卫青、霍去病统兵大破匈奴。为了有效地阻止匈奴奴隶主的突然袭击，除了抗击之外，必须要加强经常的防御工事。**修筑长城以抗匈奴，是秦始皇时即已行之有效的办法。**

# %% [markdown]
# &emsp;&emsp;明朝建立以后，女真族又兴起于东北地区，也不断威胁边境的安全。**为了巩固北方的边防，在明朝的200多年统治中几乎没有停止过对长城的修筑工程。**

# %% [markdown]
# &emsp;&emsp;**现代研究发现，汉明长城的修葺与400mm等降水线高度重合，这不仅体现了古人的智慧，更能反映出古代民族之间的关系。长城建造的目的就是为了能抵御长城外游牧民族的入侵，加强中原地区平静安宁。而400mm等降水线也正好是农耕文明与游牧文明的分界线，将种植业与畜牧业分隔开。**

# %% [markdown]
# &emsp;&emsp;生活在长城以内的人们以种植为生，长城以外的人以畜牧为生，互不干扰本是十分美好的愿景。可惜，由于季风气候的影响，畜牧总有周期，在缺少粮食的情况下，游牧民族选择进攻中原，烧杀抢掠，所以这就是两种文明之间的矛盾。

# %% [markdown]
# &emsp;&emsp;**“胡焕庸线”既是地理学意义上的人口密度分界线，又是历史学意义上的各民族竞争发展的生命线，同时也是民族学意义上的民族碰撞互动的交融线。**

# %% [markdown]
# &emsp;&emsp;**汉代建立起中原王朝的一个初步形态**，后几经繁衍变化至今天的中国疆域，而其中又尤以汉武帝对疆域的拓展最具开创意义。

# %% [markdown]
# &emsp;&emsp;**唐朝建立了一种比较平等的民族关系**，促进了以汉族为主体的各民族间的团结、和睦和经济文化的交流，有利于统一多民族国家的发展和巩固。

# %% [markdown]
# &emsp;&emsp;**明初在外蒙古边境一带设置四十余个卫所为边防前线**，包括东胜卫、斡难河卫、开平卫、大宁卫等皆为明朝边防重地，其走向大致为阴山、大青山、西拉木伦河一线。永乐以后，由于天气转寒，农耕不济，致使边境逐渐南移。明中期，随着蒙古复振，边境再次内迁，并修建长城以防御蒙古，在长城沿线设九边重镇加强防御，长城也成为当时农耕区与游牧区的界线。

# %% [markdown]
# &emsp;&emsp;对于古代，游牧民族的入侵一直是一个大问题，游牧民族马上进攻能力强，机动性灵活，故历朝历代都有被外族入侵的经历。但是从汉唐明的疆域图我们可以看到，这三个朝代不仅版图大大超越了400mm等降水线，甚至有些直接入侵到现在的欧洲地区。游牧民族是在马背上的民族，特别擅长马战，长城以外平原广阔正是他们施展的好地方，而这三个国家能将本身的版图扩张到长城以外，**主要原因就是这几个国家综合国力强盛，不管是汉武帝的“犯我强汉者，虽远必诛”，还是唐朝的多元民族平等关系，万邦来朝，或者是汉朝的“厚往薄来”，都是基于强盛的国力，使他们能强势得突破400mm等降水线而不畏惧游牧文明。**

# %% [markdown]
# ## 3 技术思路和解决方案

# %% [markdown]
# ### 3.1 技术思路

# %% [markdown]
# &emsp;&emsp;根据题目要求，需要我们在地图上画出上述要求的线。这里必须考虑选择什么年代的地图，为了更清晰的表现出古代疆域与当前疆域的对比以及实时显示胡焕庸线和400mm降水线，我们采用的是现代**新中国成立后的地图**。所以本题的需求就变成了如何在地图上将要求的几条线画出以及用恰当的方式展示出来。

# %% [markdown]
# &emsp;&emsp;根据上述需求，我们小组成员首先选择上网查找相应的资料，其中包括各线段含义，疆域范围等等。其中最主要的是关于如何实现上述需求，通过查找资料我们发现Python有一个folium包。**通过folium包我们可以在地图上选择必要的点**，将他们连线以达到题目要求。但是这种方法一个一个取点比较繁琐，我们小组本意是打算通过爬虫技术爬取拥有对应信息的网站的数据以实现便捷化，简单化，快速化。但是在查找资料过程中，我们发现没有那种专门的网站将所需的数据展示出来，只有一些零散的，比如对于某些疆域图可以在网上找到相应的资料实现爬虫爬取。所以，我们只能采用最原始的方法在地图上打点以实现题目要求的功能。

# %% [markdown]
# &emsp;&emsp;**代码运行后生成的文件是HTML文件**，需要通过浏览器打开才能查看，为了方便查看以及各图形之间的切换，我们还基于PYQT5完成了一个简单的可视化界面的展示。其中包括几个按钮切换打开的文件。

# %% [markdown]
# #### 3.1.2 folium包简介:

# %% [markdown]
# &emsp;&emsp;Folium是建立在Python生态系统的数据整理（Datawrangling）能力和Leaflet.js库的映射能力之上的开源库。用Python处理数据，然后用Folium将它在Leaflet地图上进行可视化。Folium能够将通过Python处理后的数据轻松地在交互式的Leaflet地图上进行可视化展示。它不单单可以在地图上展示数据的分布图，还可以使用Vincent/Vega在地图上加以标记。

# %% [markdown]
# &emsp;&emsp;这个开源库中有许多来自OpenStreetMap、MapQuest Open、MapQuestOpen Aerial、Mapbox和Stamen的内建地图元件，而且支持使用Mapbox或Cloudmade的API密钥来定制个性化的地图元件。Folium支持GeoJSON和TopoJSON两种文件格式的叠加，也可以将数据连接到这两种文件格式的叠加层，最后可使用color-brewer配色方案创建分布图。

# %% [markdown]
# &emsp;&emsp;Folium可以让你用Python强大生态系统来处理数据，然后用Leaflet地图来展示。Folium内置一些来自OpenStreetMap、MapQuest Open、MapQuest Open Aerial、Mapbox和Stamen的地图元件（tilesets），并且支持用Mapbox或者Cloudmade API keys来自定义地图元件。Folium支持GeoJSON和TopJSON叠加（overlays），绑定数据来创造一个分级统计图（Choropleth map）。但是，Folium库绘制热点图的时候，需要联网才可显示。

# %% [markdown]
# #### 3.1.3 PYQT5简介

# %% [markdown]
# &emsp;&emsp;pyqt5是一套Python绑定Digia QT5应用的框架。它可用于Python 2和3。本教程使用Python 3。Qt库是最强大的GUI库之一。pyqt5做为Python的一个模块，它有620多个类和6000个函数和方法。这是一个跨平台的工具包，它可以运行在所有主要的操作系统，包括UNIX，Windows，Mac OS。pyqt5是双重许可。开发者可以在GPL和商业许可之间进行选择。

# %% [markdown]
# #### 3.1.4爬虫技术

# %% [markdown]
# &emsp;&emsp;网络爬虫(Web Crawler），是一种按照一定的规则，自动提取Web网页的应用程序或者脚本，它是在搜索引擎上完成数据抓取的关键一步，可以在Internet上下载网站页面。爬虫是为了将Internet上的网页保存到本地，爬虫是从一个或多个初始页面的URL,通过分析页面源文件的URL，抓取新的网页链接，通过这些网页链接，再继续寻找新的网页链接，反复循环，直到抓取和分析所有页面。这是理想情况下的执行情况，根据现在公布的数据，最好的搜索引擎也只爬取整个互联网不到一半的网页。

# %% [markdown]
# ### 3.2 解决方案

# %% [markdown]
# #### 3.2.1 folium包

# %% [markdown]
# &emsp;&emsp;对于folium包的使用，只需要简单几行代码就可以实现生成地图并在地图上打点以及连线的功能。下面是项目中生成胡焕庸线的代码。

# %%
import folium
hhy_location = [[50.250904, 127.530888],[25.027664, 98.487817]]
hhy = folium.Map([30.7513, 103.9746], zoom_start=4, control_scale=True, world_copy_jump=False,
                     no_wrap=True)  # 中心区域的确定

hhy.add_child(folium.LatLngPopup())
hhy.add_child(folium.ClickForMarker())

hhyroute = folium.PolyLine(  # polyline方法为将坐标用线段形式连接起来
    hhy_location,  # 将坐标点连接起来
    weight=3,  # 线的大小为3
    color='orange',  # 线的颜色为橙色
    opacity=0.8  # 线的透明度
    ).add_to(hhy)  # 将这条线添加到刚才的区域m内

hhy.save(os.path.join(r'C:\Users\zlx\Desktop', '胡焕庸线.html'))  # 将结果以HTML形式保存到桌面上

# %% [markdown]
# &emsp;&emsp;对于上述代码，hhy_location表示胡焕庸线黑河腾冲两点的经纬度列表，在hhyroute = folium.PolyLine时调用。通过folium.Map()可以设置打开时焦点位置以及放大倍数以及对地图的初始化。通过hhy.add_child(folium.LatLngPopup())和hhy.add_child(folium.ClickForMarker())可以设置显示坐标位置以及坐标点。通过folium.PolyLine()函数可以将hhy_location列表中的点两两相连并且设置一些基本属性。

# %% [markdown]
# #### 3.2.2 爬虫技术

# %% [markdown]
# &emsp;&emsp;爬虫的代码比较基础，没有什么特别的难点，最难的就是爬虫的第一步网页分析，WorldMap网站疆域边界数据不是直接显示再网页原码里的。通过分析我们发现鼠标点击疆域部分后疆域边界会画红线，我们发现Network里有一个WFS请求，通过使用这个请求的Request URL，获取到了一段gml代码数据，刚开始使用xpath爬取，但是标签规则好像和html不同，没法爬取我需要的数据，后来采用正则表达式来获取边界数据，但是发现数据中有多处相同的标签，最后使用两次正则表达式取出边界数据。总共要获取三个朝代边界，由于每个朝代的边界数据请求URL不同且没有规律，我就将四个URL放到一个数组里（明疆域有两段），多次调用爬虫函数生成四个文件。

# %%
import requests
import random
import re

class Spider:
    def __init__(self):
        # 1582明东部
        # self.url ="http://worldmap.harvard.edu/geoserver/wms?service=WFS&request=GetFeature&version=1.0.0&srsName=EPSG:900913&outputFormat=GML2&typeName=geonode:_ming_9uv&BBOX=14835213.891284,6432224.019694,15030892.683667,6627902.812077,EPSG:900913&_dc=1577203760243"
        # 1582明西部
        # self.url ="http://worldmap.harvard.edu/geoserver/wms?service=WFS&request=GetFeature&version=1.0.0&srsName=EPSG:900913&outputFormat=GML2&typeName=geonode:_ming_9uv&BBOX=12076142.918687,4044942.752623,12271821.711069,4240621.545006,EPSG:900913&_dc=1577203651121"
        # 公元前82年汉
        # self.url = "http://worldmap.harvard.edu/geoserver/wms?service=WFS&request=GetFeature&version=1.0.0&srsName=EPSG:900913&outputFormat=GML2&typeName=geonode:han_in_82_bce_9wx&BBOX=9199664.670659,5003768.835299,9395343.463042,5199447.627682,EPSG:900913&_dc=1577203526319"
        # 公元741年唐
        # self.url = "http://worldmap.harvard.edu/geoserver/wms?service=WFS&request=GetFeature&version=1.0.0&srsName=EPSG:900913&outputFormat=GML2&typeName=geonode:tang_empire_741_slg&BBOX=14010160.352042,5803956.712671,14205839.144425,5999635.505054,EPSG:900913&_dc=1577114124065"
        self.url = [
            "http://worldmap.harvard.edu/geoserver/wms?service=WFS&request=GetFeature&version=1.0.0&srsName=EPSG:900913&outputFormat=GML2&typeName=geonode:_ming_9uv&BBOX=14835213.891284,6432224.019694,15030892.683667,6627902.812077,EPSG:900913&_dc=1577203760243",
            "http://worldmap.harvard.edu/geoserver/wms?service=WFS&request=GetFeature&version=1.0.0&srsName=EPSG:900913&outputFormat=GML2&typeName=geonode:_ming_9uv&BBOX=12076142.918687,4044942.752623,12271821.711069,4240621.545006,EPSG:900913&_dc=1577203651121",
            "http://worldmap.harvard.edu/geoserver/wms?service=WFS&request=GetFeature&version=1.0.0&srsName=EPSG:900913&outputFormat=GML2&typeName=geonode:han_in_82_bce_9wx&BBOX=9199664.670659,5003768.835299,9395343.463042,5199447.627682,EPSG:900913&_dc=1577203526319",
            "http://worldmap.harvard.edu/geoserver/wms?service=WFS&request=GetFeature&version=1.0.0&srsName=EPSG:900913&outputFormat=GML2&typeName=geonode:tang_empire_741_slg&BBOX=14010160.352042,5803956.712671,14205839.144425,5999635.505054,EPSG:900913&_dc=1577114124065"
        ]
        self.headers = [
            "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36",
            "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36",
            "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:30.0) Gecko/20100101 Firefox/30.0",
            "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.75.14 (KHTML, like Gecko) Version/7.0.3 Safari/537.75.14",
            "Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; Win64; x64; Trident/6.0)",
            'Mozilla/5.0 (Windows; U; Windows NT 5.1; it; rv:1.8.1.11) Gecko/20071127 Firefox/2.0.0.11',
            'Opera/9.25 (Windows NT 5.1; U; en)',
            'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; .NET CLR 1.1.4322; .NET CLR 2.0.50727)',
            'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.5 (like Gecko) (Kubuntu)',
            'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.8.0.12) Gecko/20070731 Ubuntu/dapper-security Firefox/1.5.0.12',
            'Lynx/2.8.5rel.1 libwww-FM/2.14 SSL-MM/1.4.1 GNUTLS/1.2.9',
            "Mozilla/5.0 (X11; Linux i686) AppleWebKit/535.7 (KHTML, like Gecko) Ubuntu/11.04 Chromium/16.0.912.77 Chrome/16.0.912.77 Safari/535.7",
            "Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:10.0) Gecko/20100101 Firefox/10.0 "
        ]

    def get_url(self, n):
        dynasty = ['明东部', '明西部', '汉', '唐']
        url=self.url[n]
        dynasty=dynasty[n]
        return url, dynasty

    def get_coordinate(self, url, dynasty):
        headers = {
            "User-Agent": random.choice(self.headers)  # 随机选择请求头，模拟不同的浏览器
        }
        response = requests.get(url, headers=headers)
        html = response.content

        keyword1 = re.compile(r'<gml:outerBoundaryIs>(.*)</gml:outerBoundaryIs>')
        outerBoundary = re.findall(keyword1, html.decode('utf-8'))
        keyword2 = re.compile(r'(\d+.\d+,\d+.\d+)')
        coordinate = re.findall(keyword2, outerBoundary[0])
        # print(coordinate)

        for i in coordinate:
            f = open(dynasty, 'a', encoding='utf-8')
            f.write(i + '\n')
            f.close()

    def __call__(self, *args, **kwargs):
        for n in range(0, 4):
            url, dynasty = self.get_url(n)
            self.get_coordinate(url, dynasty)



def main():
    link = Spider()
    link()


if __name__ == '__main__':
    main()

# %% [markdown]
# #### 3.2.3 基于PYQT5的可视化界面

# %% [markdown]
# &emsp;&emsp;代码中构造了2类控件，包括七个按钮和1个QWebEngineView，它们通过水平布局以及垂直布局展示在大小为800×600的窗体内。其中每个按钮都对应着一个按钮相应函数，负责切换界面显示的网页内容。

# %%
import sys
from PyQt5.QtCore import QUrl
from PyQt5.QtGui import *
from PyQt5.QtWidgets import *
from PyQt5.QtWebEngineWidgets import *

class Example(QWidget):

    def __init__(self):
        super().__init__()

        self.initUI()

    def initUI(self):
        self.url = ' '
        jsButton = QPushButton("400mm降水线")
        hhyButton = QPushButton("胡焕庸线")
        hccButton = QPushButton("汉长城")
        mccButton = QPushButton("明长城")
        hButton = QPushButton("汉")
        tButton = QPushButton("唐")
        mButton = QPushButton("明")
        jsButton.clicked.connect(self.js_buttonClicked)
        hhyButton.clicked.connect(self.hhy_buttonClicked)
        hccButton.clicked.connect(self.hcc_buttonClicked)
        mccButton.clicked.connect(self.mcc_buttonClicked)
        hButton.clicked.connect(self.h_buttonClicked)
        tButton.clicked.connect(self.t_buttonClicked)
        mButton.clicked.connect(self.m_buttonClicked)

        self.browser = QWebEngineView()
        self.browser.load(QUrl('file:///C:/Users/zlx/Desktop/' + self.url))

        hbox = QHBoxLayout()
        hbox.addStretch(1)
        hbox.addWidget(jsButton)
        hbox.addWidget(hhyButton)
        hbox.addWidget(hccButton)
        hbox.addWidget(mccButton)
        hbox.addWidget(hButton)
        hbox.addWidget(tButton)
        hbox.addWidget(mButton)

        vbox = QVBoxLayout()
        vbox.addStretch(1)
        vbox.addWidget(self.browser)
        vbox.addLayout(hbox)

        self.setLayout(vbox)

        self.setGeometry(300, 300, 800, 600)
        self.setWindowTitle('Map')
        self.show()

    def js_buttonClicked(self):
        self.url='400mm降水线.html'
        self.browser.load(QUrl('file:///C:/Users/zlx/Desktop/' + self.url))

    def hhy_buttonClicked(self):
        self.url = '胡焕庸线.html'
        self.browser.load(QUrl('file:///C:/Users/zlx/Desktop/' + self.url))

    def hcc_buttonClicked(self):
        self.url = '汉长城.html'
        self.browser.load(QUrl('file:///C:/Users/zlx/Desktop/' + self.url))

    def mcc_buttonClicked(self):
        self.url = '明长城.html'
        self.browser.load(QUrl('file:///C:/Users/zlx/Desktop/' + self.url))

    def h_buttonClicked(self):
        self.url = '汉.html'
        self.browser.load(QUrl('file:///C:/Users/zlx/Desktop/' + self.url))

    def t_buttonClicked(self):
        self.url = '唐.html'
        self.browser.load(QUrl('file:///C:/Users/zlx/Desktop/' + self.url))

    def m_buttonClicked(self):
        self.url = '明.html'
        self.browser.load(QUrl('file:///C:/Users/zlx/Desktop/' + self.url))



if __name__ == '__main__':
    app = QApplication(sys.argv)
    ex = Example()
    sys.exit(app.exec_())

# %% [markdown]
# ## 4 运行结果

# %% [markdown]
# &emsp;&emsp;本次实验的实验环境是Win10+Pycharm，并没有在jupyter上运行过，故运行结果仅给出Pycharm上的结果，jupyter可在环境配置完成后简单将代码移植实现。

# %% [markdown]
# ### 4.1 400mm降水线运行结果：

# %% [markdown]
# ![400mm.jpg](attachment:400mm.jpg)

# %% [markdown]
# ### 4.2 胡焕庸线运行结果：

# %% [markdown]
# ![hhy.jpg](attachment:hhy.jpg)

# %% [markdown]
# ### 4.3 汉长城运行结果：

# %% [markdown]
# ![hcc.jpg](attachment:hcc.jpg)

# %% [markdown]
# ### 4.4 明长城运行结果

# %% [markdown]
# ![mcc.jpg](attachment:mcc.jpg)

# %% [markdown]
# ### 4.5 汉朝疆域

# %% [markdown]
# ![h.jpg](attachment:h.jpg)

# %% [markdown]
# ### 4.6 唐朝疆域

# %% [markdown]
# ![t.jpg](attachment:t.jpg)

# %% [markdown]
# ### 4.7 明朝疆域

# %% [markdown]
# ![m.jpg](attachment:m.jpg)

# %% [markdown]
# ### 4.8 他们与古代民族的关系

# %% [markdown]
# &emsp;&emsp;在2.8已经简单的介绍了400mm等降水线、胡焕庸线、汉长城、明长城、汉唐明疆域与我们古代民族的关系。2.8已经简单介绍了400mm降水线是种植文明与畜牧文明的分界线，由于气候、人心等原因两个文明经常出现冲突。还介绍了胡焕庸线是我国人口密度的分界线，汉明长城与400mm等降水线高度重合，汉唐明以其自身强悍的国力，强势将领土扩张到400mm降水线以外，以他们各自的对游牧民族的政策实现对游牧民族的管治。接下来就详细分析400mm等降水线、胡焕庸线、汉明长城、汉唐明疆域与我国古代民族的关系。

# %% [markdown]
# #### 4.8.1 400mm降水线与我国古代民族之间的关系

# %% [markdown]
# &emsp;&emsp;400毫米等降水量线，是我国一条重要的地理分界线，它大致经过：大兴安岭—张家口—兰州—拉萨—喜马拉雅山脉东部。主要是半湿润与半干旱区分界线。是半湿润区与半干旱区的分界线。是种植业与畜牧业分界线。是农耕文明与游牧文明的分界线。是西北地区与北方地区分界线。400mm降水量线把我国大致分为东南与西北两大半壁。400毫米等降水量线是我国季风区与非季风区的划分界线。

# %% [markdown]
# &emsp;&emsp;正如古希腊的小块平原有助于形成天然的政治单位——小国寡民的城邦一样，古代中国广袤的冲击平原也有助于形成庞大的农耕帝国和专制政体。也就是说，地理环境左右着一个地区的原始文明走向。

# %% [markdown]
# &emsp;&emsp;按说，优越的地理环境足以让中原百姓倍感优越与幸运。然而，它并未给人们带来预想的安全感。因为，在古代中国西北部，有一条令人寝食难安的线。这条线，在中国地理课本上叫400毫米等降水量线。这条线的两侧，生态环境迥异，生活方式不同，生活资料互补，又有大山的分割，农耕区的农民日出而作，日落而息，春种秋收，男耕女织，一年到头忙碌而充实；游牧区的牧民逐水草而迁徙，扬鞭放牧，弯弓狩猎，一天到晚豪迈而惬意。每到农闲季节，农民拿出多余的粮食与布匹，牧民取出多余的牲畜与皮货，双方在规定的地点进行易货贸易，各取所需，互通有无，这是一种多么理想、多么祥和的农牧关系呀！但理想一向丰满，现实往往骨感。每当遇到气候干旱、牧草枯萎、牛羊锐减的年份，非季风区饥肠辘辘的牧民，根本没有多余的生活资料向农民换取救命的粮食，只能冒着生命危险偷偷闯入季风区，前去盗窃和劫掠通常有半年积蓄的种田人。零星的袭击渐渐扩大为战争，防守者则企图报复，有时也全面出击以图后发制人。这一根本原因，导致牧民与农民沿400毫米等降水线开始了连亘两千年的血腥战争。边关烽烟和战马嘶鸣，从此成为两侧民众无边的噩梦。

# %% [markdown]
# &emsp;&emsp;游牧区并非弱者，他们一直通过两种方法获取必需的生活资料，一是战争，二是贸易，而贸易的成本无疑更低。在春秋战国时期，中原诸侯国竞相与草原部落进行贸易，以便从草原买到战马用于诸侯国之间的兼并。久而久之，诸侯国之间的竞争关系使得草原与内地的贸易达到了一个大致的市场均衡价格，至于那些年久失修的诸侯国长城，就像如今农村家庭的门锁和高墙一样，逐渐沦落为防君子不防小人的摆设。

# %% [markdown]
# &emsp;&emsp;然而，当中原走向统一，为了统治区的绝对安宁，就会强制关闭原诸侯国与游牧区的边境贸易，继而在边境派驻大量的军民屯田驻戌，甚至屡屡像秦始皇一样不断加高、加固古老的长城，将游牧部落彻底隔绝在所谓的农耕文明区之外。如此一来，草原上那些可怜的小部落，通过战争获取生活资料就成了唯一的选择。要想赢得与中原王朝的战争，小部落必须联合起来成为一个大的部落联盟。于是，强大的游牧帝国出现了。

# %% [markdown]
# &emsp;&emsp;就这样，从秦代开始，长城两侧呈现出两种截然不同的政治和军事形态。前一种是在中原王朝强盛时期，中原王朝凭借强大的军事、经济实力与兵强马壮的草原帝国在长城一线形成对峙局面，双方你来我往，时战时和，而短暂的和平常常是由中原王朝通过付出财富和女人完成的，如汉vs匈奴，西晋vs鲜卑，隋、唐vs突厥，宋vs辽、金、西夏，明vs瓦剌、后金等；后一种是在中原政权内讧、衰退时期，游牧帝国趁机越过长城，逐鹿中原，然后吸收中原地区的先进文化，形成了定居民族与游牧民族统一、融合的多元帝国，如北魏、前秦、北齐、北周、元、清等。

# %% [markdown]
# &emsp;&emsp;天长日久，由于多元帝国的持续作用，400毫米等降水线的两侧，都划入了中国版图；生活在两侧的人民，都已成为中华民族的一分子。多元帝国治下的长城，已经不再是一道防御性的城墙，充其量只能算是一个国家之内的两个邻居间的一道篱笆，多数时间是供远方游人浏览与感悟的一道风景，更多的意义则是中国56个民族共同的人文地标和精神图腾。

# %% [markdown]
# &emsp;&emsp;战马远去，烽烟已熄，一切都在变，不变的，似乎还是那条绵延万里的400毫米等降水线，以及线上的苍凉奇观。

# %% [markdown]
# #### 4.8.2 胡焕庸线与我国古代民族之间的关系

# %% [markdown]
# &emsp;&emsp;“胡焕庸线”既是地理学意义上的人口密度分界线，又是历史学意义上的各民族竞争发展的生命线，同时也是民族学意义上的民族碰撞互动的交融线。

# %% [markdown]
# &emsp;&emsp;“胡焕庸线”是我国著名地理学家胡焕庸先生在1935年提出的划分我国人口密度的分界线。这条线从黑龙江省的黑河市到云南省的腾冲市，是一条大致呈45度倾斜的基本直线。2014年底，李克强总理在参观人居科学研究展览时，高度关注“胡焕庸线”，并提出“‘胡焕庸线’能否被突破”的重大议题。我认为，“胡焕庸线”不仅是我国人口密度的分界线，也是我国历史上游牧民族和农耕民族的交融线，我们可以试从民族交融发展的视角思考李克强总理提出的突破“胡焕庸线”的议题。历史上，“胡焕庸线”以西的游牧民族之间发生着相互交融，这些游牧民族与“胡焕庸线”以东的农耕民族之间也发生着相互交融。

# %% [markdown]
# &emsp;&emsp;“胡焕庸线”作为我国人地关系的重大地理发现，其形成有着深刻的历史和地理原因。展开我国的历史地图，我们不难发现，历史上众多的军事要地皆分布在“胡焕庸线”附近。自东北向西南分别有幽云十六州、关中地区、汉中地区、河洛地区、巴蜀地区等，这些地区均是“兵家必争之地”。如果再细致地观察这条线附近的城市，可以看到有北京、西安、成都、汉中、太原、大同、大理、黑河、齐齐哈尔等，这些城市在我国历史上的地位和分量不言而喻。著名的经济地理学学者王铮认为，地貌、气候等自然禀赋是“胡焕庸线”的第一地理本性，若要突破“胡焕庸线”，必须借助交通和人口－产业集聚等第二地理本性。“胡焕庸线”以东地区气候较为湿润，地貌以平原、丘陵为主，是我国传统的农耕区，以43．7％的国土面积养育了94．4％的人口；“胡焕庸线”以西地区气候以干旱、半干旱的大陆性气候为主，地貌以高原、沙漠为主，是我国传统的牧区，国土面积占全国总面积的56．3％，而人口只占5．6％。一般来讲，“胡焕庸线”大体与我国400毫米年等降水量线重合，是我国半干旱区和半湿润区的分界线。“胡焕庸线”的这些历史和地理特征造就了其东、西两侧的人口分布差异。如要突破“胡焕庸线”，需综合考虑其历史、地理和民族等各方面特征，打破“中心－腹地”式的传统空间结构，发展“枢纽－网络”型的空间结构。

# %% [markdown]
# &emsp;&emsp;各民族在文化交融发展的过程中增进彼此之间的了解，有利于增强族际之间的情感认同，增强对中华文化的认同。习近平总书记在2014年召开的中央民族工作会议上指出，“加强中华民族大团结，长远和根本的是增强文化认同，建设各民族共有精神家园，积极培养中华民族共同体意识”。“胡焕庸线”作为贯穿我国东北－西南的民族交融线，是历史上各民族文化接触、互动、交融的重要场域。在实现中华民族伟大复兴的中国梦的历史进程中，增强各族群众对伟大祖国、中华民族、中华文化、中国共产党、中国特色社会主义的认同，有助于巩固多民族国家的稳定与统一。3．推动民族工作进步
# 民族交融表现在民族工作方面，即各民族的共同繁荣发展、共同团结进步。各民族在相互学习的过程中，形成了平等、团结、互助、和谐的社会主义新型民族关系，为构建中华民族共同体提供物质和精神方面的支持。历史上，活跃于“胡焕庸线”附近的各民族在长期的交往交流交融过程中，形成了你中有我、我中有你的多元统一体。在“多元一体”的结构中，各民族之间的差异性逐渐缩小，共同性渐趋增强，这就为民族工作的开展提供了精神文化和道德情感上的保障。各民族同胞齐心协力、共商共建，为实现中华民族伟大复兴的中国梦共同团结奋斗。

# %% [markdown]
# #### 4.8.3 汉长城与民族关系

# %% [markdown]
# &emsp;&emsp;元朔年间，匈奴不断入辽西、上谷、渔阳杀掠吏民，武帝命卫青、霍去病统兵大破匈奴。为了有效地阻止匈奴奴隶主的突然袭击，除了抗击之外，必须要加强经常的防御工事。修筑长城以抗匈奴，是秦始皇时即已行之有效的办法。

# %% [markdown]
# &emsp;&emsp;汉初，匈奴乘中原战乱，越过秦蒙恬所筑长城，复与汉以战国秦、赵、燕长城为界。由于这条长城年久失修，北方守军稀少，因此，强大的匈奴不断进入长城以内掳掠，一直深入到代谷、太原、西河、上郡、北地等郡，汉高祖、惠帝、文帝、景帝被迫对匈奴采取和亲政策；嫁公主给单于为阏氏（即王后），并赐予大量的财物。但是，就是这样一条破烂不堪的长城，也在一定程度上发挥了军事防御作用如果不是匈奴大军，一般不能进入长城掳掠。其次，如果守将得力，纵有匈奴大军，也进不了长城。程不识也是守长城的名将，与李广齐名，他治军很严，随时防御匈奴突袭，匈奴也不敢来犯，也说明战国长城起了一定作用。其后卫青、霍去病、公孙贺、公孙敖等出击匈奴，均以赵、秦长城为进攻退守的主要据点。这表明，直到西汉前期，战国秦、赵、燕长城仍在发挥军事防御作用，虽然它的防御能力已大不如战国时期了。直到汉武帝把匈奴赶到漠北以后，修复蒙恬所筑秦长城和修建外长城，这条战国秦、赵、燕长城才被放弃，它的军事防御作用也才随之终结。据史料记载，汉代长城修筑于公元前121年（汉武帝元狩二年）。当时北方的匈奴势力强大，常侵犯河西一带，劫掠财粮牲畜，骚扰汉民农耕。为使边疆安宁，汉武帝多次采取大规模的军事行动进行西征。打败匈奴后，他开始向河西迁徙汉族居民，然后进行农业开发，紧接着在这里驻扎军队，修筑长城，以阻止匈奴再次入侵。因此，汉代长城是在中国封建社会中第一次进行西部大开发的重要历史见证。这也为此后在新疆建立西域都护府、畅通丝绸之路奠定了重要的历史基础。

# %% [markdown]
# #### 4.8.4 明长城与民族关系

# %% [markdown]
# &emsp;&emsp;明朝建立以后，女真族又兴起于东北地区，也不断威胁边境的安全。为了巩固北方的边防，在明朝的200多年统治中几乎没有停止过对长城的修筑工程。明代长城的修建过程，大体可以分为三个阶段： [7]
# 明前期（1368～1447）对长城的修缮明朝开国之初，国势强盛，明太祖洪武五年（1372），出兵15万分二路进击漠北，西路打通了河西走廊，设置甘州、庄浪诸卫。洪武二十年（1387），大将军冯胜、蓝玉经略东北，将边界推进到大兴安岭以西，明成祖朱棣即位后，永乐八至二十二年（1410～1424）的15年间，先后5次发兵，深入漠北，迫使瓦剌和鞑靼分别接受了明王朝的册封。明王朝的北部边防线推进到大兴安岭、阴山、贺兰山以西以北一带。明前期的长城工程主要是在北魏、北齐、隋长城的基础上，“峻垣深壕，烽堠相接。”“各处烟墩务增筑高厚，上贮五月粮及柴薪药弩，墩旁开井……”，“自长安岭（今宣化境内）迤西，至洗马林（今山西天镇），皆筑石垣，深壕堑”（《明会要》卷63边防），即增建烟墩、烽堠、戍堡、壕堑，局部地段将土垣改成石墙。修缮重点是北京西北至山西大同的外边长城和山海关至居庸关的沿边关隘。 [8]
# 明中叶（1448～1566）长期的大规模兴筑。“土木之变”以后，瓦剌、鞑靼不断兴兵犯边掳掠，迫使明王朝把修筑北方长城，增建墩堡做为当务之急。百余年间建成以下长城重镇。

# %% [markdown]
# &emsp;&emsp;明代在军事上抵御少数民族的侵扰，在经济上促进了边疆经济开发，政治上巩固了多民族国家的统一。而 明长城是中国历史上费时最久，工程最大，防御体系和结构最为完善的长城工程，它对明朝防御掠扰，保护国家安全和人民生产生活的安定，开发边远地区，保护中国与西北域外的交通联系都起过不小的作用。它充分体现了中国古代建筑工程的高度成就和古代劳动人民的聪明才智。

# %% [markdown]
# #### 汉朝疆域图与民族关系

# %% [markdown]
# &emsp;&emsp;汉代建立起中原王朝的一个初步形态，后几经繁衍变化至今天的中国疆域，而其中又尤以汉武帝对疆域的拓展最具开创意义。

# %% [markdown]
# &emsp;&emsp;汉武帝在位的前40年(公元前140～前100年)，汉朝一方面恢复并巩固秦朝原有领土，另一方面则进一步拓展疆域。对北方疆域的开拓，是以对匈奴战争开始的。汉武帝反击匈奴之战，始于公元前129年，共历时三四十年之久。

# %% [markdown]
# &emsp;&emsp;在这一时期内，汉军以卫青、霍去病为将领，对匈奴展开三次重大反击作战，并取得决定性的胜利，夺回河套地区，也解除匈奴对长安的威胁;而被歼15万人的匈奴被迫退往大漠以北，人畜锐减，开始走向衰落。自此，“汉朝将北部疆界巩固在阴山一线”。

# %% [markdown]
# &emsp;&emsp;公元前121年，霍去病出击河西，俘获了匈奴浑邪王的儿子。不久，浑邪王杀了不肯投降的休屠王，率众降汉。这样，汉朝的疆域扩大到了整个河西走廊和湟水流域——即今青海湖以东、祁连山东北地区，先后设置了酒泉、武威、张掖、敦煌和金城五个郡。由于汉朝控制了河西走廊，通向西域的大门已经打开。

# %% [markdown]
# &emsp;&emsp;在汉武帝继位的第十年左右(公元前130年)，武帝就征发士兵推进西南，并在那一带新设了十几个县。但由于筑路工程非常艰巨，加上汉朝正忙于对付匈奴，一度曾取消了部分新设的县。

# %% [markdown]
# &emsp;&emsp;在东北，两汉初年，中原人卫满率领数千人进入朝鲜半岛，建立了自己的政权。公元前109年，武帝用兵朝鲜，次年朝鲜投降，“把东北疆界推至朝鲜半岛中北部和辽东一带”。

# %% [markdown]
# &emsp;&emsp;对岭南的统一已是大势所趋。虽然在汉之前，秦朝已在岭南建立了郡县，但并没有得到巩固。公元前113年，武帝召南越王来长安朝见。第二年，反对并入汉朝的南越丞相吕嘉杀了国王和汉使，发动叛乱。汉军分五路进攻，俘获吕嘉。

# %% [markdown]
# &emsp;&emsp;西汉的疆域在武帝后期达到极盛。

# %% [markdown]
# #### 4.8.4 唐朝疆域图与民族关系

# %% [markdown]
# &emsp;&emsp;唐朝建立了一种比较平等的民族关系，促进了以汉族为主体的各民族间的团结、和睦和经济文化的交流，有利于统一多民族国家的发展和巩固。
# 唐承隋制后，制定和实行了比较开明的民族政策，较好地处理了当时的民族关系，使统一的多民族国家的发展进入了一个新的历史时期。唐朝的疆域空前辽阔，“东极于海，西至焉耆，南尽林邑，北抵大漠，皆为州县”。唐朝的统治，在南方所达到的地方大致与隋朝相同，在北方则扩展至小海（今贝加尔湖）以北，西方至今咸海，东北到今黑龙江中游至外兴安岭以北。唐代的疆域超过汉代，是我国古代疆域最为广阔的王朝之一。

# %% [markdown]
# &emsp;&emsp;在唐朝辽阔的疆域里，可以分为两个部分，一是以汉族为核心的中原地区，包括黄河中下游、长江中下游、珠江流域，二是周边的少数民族地区。唐朝对周边少数民族的管理实行羁縻府州制度。百余年间，在突厥、回纥、党项、吐谷浑、契丹和南方羌、蛮地区共设立了856个羁縻府州。为了管理和监督羁縻府州，唐廷先后设立了安西、北庭、单于、安南等都护府。在没有设都护府的地区，由边州都督府统领。通过羁縻府州制度，唐朝建立了一种比较平等的民族关系，促进了以汉族为主体的各民族间的团结、和睦和经济文化的交流，有利于统一多民族国家的发展和巩固。

# %% [markdown]
# &emsp;&emsp;唐朝统治者还通过册封、和亲等政策协调和加强与各民族的关系，并取得了前所未有的成功。唐太宗曾把衡阳长公主嫁到西突厥，把弘化公主嫁到吐谷浑，而文成公主嫁到吐蕃，唐、蕃和亲更是一个成功的范例。唐、蕃和亲奠定了双方友好的关系，使双方经济、文化交流日益频繁。穆宗初年，唐、蕃分别在长安、逻些会盟，至今拉萨大昭寺前还树立着长庆会盟碑，碑上铭刻着“舅甥二主商议，社稷如一，结立大和盟约，永不渝替”的字样，可见和平亲善，“和同为一家”始终是唐、蕃关系的主流，和亲政策在其中发挥了重要的作用。

# %% [markdown]
# &emsp;&emsp;由于唐王朝实行比较开明的民族政策，因而在唐代，尤其是唐前期，各少数民族之间，各少数民族与汉族之间经济、文化联系密切，出现了胡越一家、天下一家的兴旺景象。贞观二十一年（647），西北各少数民族修筑了一条通往长安的“参天可汗道”，沿途设置68个驿站，以供往来使者食宿和马匹。

# %% [markdown]
# &emsp;&emsp;周边各民族对以汉族为主体的中原地区的影响也是很大的。少数民族在唐朝的政治生活中，特别是在军事上起了很大的作用。在唐朝上层统治集团中，蕃人占有相当的比重，在战争中涌现出一大批著名的蕃将，如史大奈、阿史那杜尔、执失思力、哥舒翰等为突厥人，冯盎为汉越混血人，契芯片何力、仆固怀恩、浑城等为铁勒人，黑齿常之为百济人，泉男生、泉献诚父子、王毛仲、高仙芝等为高丽人，突地稽、李谨行父子、李怀光等为靺鞨人，契丹和奚出身的有李光弼、李光进兄弟等人，羌人出身的有荔非元礼等，沙陀出身的有李国昌、李克用等。这些蕃将及其统率的军队在唐朝的军事活动中发挥着极其重要的作用。

# %% [markdown]
# &emsp;&emsp;从服饰、饮食、生活习俗，整个唐代，少数民族的影响广泛存在。汉族和各族人民一起创造了强大的唐王朝和辉煌的唐文化。

# %% [markdown]
# #### 4.8.5 明朝疆域图与民族关系

# %% [markdown]
# &emsp;&emsp;明初在外蒙古边境一带设置四十余个卫所为边防前线，包括东胜卫、斡难河卫、开平卫、大宁卫等皆为明朝边防重地，其走向大致为阴山、大青山、西拉木伦河一线。永乐以后，由于天气转寒，农耕不济，致使边境逐渐南移。明中期，随着蒙古复振，边境再次内迁，并修建长城以防御蒙古，在长城沿线设九边重镇加强防御，长城也成为当时农耕区与游牧区的界线。

# %% [markdown]
# &emsp;&emsp;长城是我国历史上修建的一道军事防御工事，其性质并不等同於现今“国与国”之间的界碑。比如，战国时期，各诸侯国都修筑长城。不但毗邻游牧民族的秦、赵、燕修筑长城，就连齐、楚等远离游牧民族的诸侯国也修筑长城。而长城绝不是修筑在国境线上，以作彼此之界用的，而只能是依地势修筑以便於防御。所以，不能是秦朝也好，还是明朝也好，修筑长城的位置也都差不多。

# %% [markdown]
# &emsp;&emsp;据《明史·地理志》记载：自黄帝画野置监，唐、虞分州建牧，沿及三代，下逮宋、元，废兴因革，前史备矣。明太祖奋起淮右，首定金陵，西克湖、湘，东兼吴、会，然后遣将北伐，并山东，收河南，进取幽、燕，分军四出，芟除秦、晋，讫於岭表。最后削平巴、蜀，收复滇南。禹迹所奄，尽入版图。近古以来，所未有也。

# %% [markdown]
# &emsp;&emsp;计明初封略，东起朝鲜，西据吐番，南包安南，北距大碛，东西一万一千七百五十里，南北一万零九百四里。自成祖弃大宁，徙东胜，宣宗迁开平於独石，世宗时复弃哈密、河套，则东起辽海，西至嘉峪，南至琼、崖，北抵云、朔，东西万余里，南北万里。其声教所讫，岁时纳贽，而非命吏置籍，侯尉羁属者，不在此数。呜呼盛矣！

# %% [markdown]
# &emsp;&emsp;即便是极尽抹黑明朝的满清官方，也不得不承认明朝之疆域乃是“近古以来，所未有也”。而历朝历代，对少数民族为主的羁縻地区，都是实施不同的统治政策。汉唐设都护府、明设都司（辽东都司，汉人为主，行政上隶属山东，不属此类）、满清设将军驻地。

# %% [markdown]
# &emsp;&emsp;而我们是农耕民族，在历史上对不适宜的农耕区并无太多的兴致，也欠缺对那些地区的开发条件。故而，一旦出现了维护成本过高的情况，也就放弃了。如唐朝的疆域虽在唐高宗时期达到了极盛，但这一极盛的疆域却只维持了四年。如果都按直接统治的区域计算的话，那么，明朝的疆域也是远迈汉唐。

# %% [markdown]
# &emsp;&emsp;满清时期，汉人为主的“关内十八省”+辽宁，为历史上的汉人居住范围，而这疆域与我们通常看到的秦朝疆域图基本差不多。但广大的江南地区，是伴随着“五胡乱华”、“安史之乱”、“宋室南渡”等三次中原大乱，才得以逐步开发。故而，秦朝对辽阔的江南之地，其统治力是微乎其微的，最多能算增加了几个居民点。而从实际统治疆域来说，随着对莽荒之地开发程度的越来越高，各大一统王朝的疆域是越来越大的。

# %% [markdown]
# &emsp;&emsp;明朝时期，平定云南，并对西南之地大规模实施“改土归流”政策，使得朝廷对西南的统治才达到了空前的高度。而其实，脱离任何一个朝代对边疆开发的贡献，而谈幅员辽阔是毫无意义的。

# %% [markdown]
# ## 5 自我评价

# %% [markdown]
# ### 5.1 项目优点

# %% [markdown]
# &emsp;&emsp;本次实现的项目是实现在地图上画出要求的几种线和疆域图。我们在项目开始初期进行了充分的资料调研，查找了许多相关网络资料，始终找不到项目所需的资料。所以我们项目的最终实现是通过对照网络山的图片手动选取一个一个的坐标制成EXCEL表格，通过读取表格中数据实现的。其中想过通过爬虫的方法爬取几个网页的数据以实现数据的自动化，比如汉唐名的疆域边界。汉唐明的疆域边界通过爬虫从worldmap的网址上爬取，但是由于政策规定经纬度坐标不能直接显示现实中的坐标，所以爬取的数据是经过加密的，因为时间有限我们未能完成解密，所爬取的数据未能使用在代码中。

# %% [markdown]
# &emsp;&emsp;爬虫的代码比较基础，没有什么特别的难点，最难的就是爬虫的第一步网页分析，WorldMap网站疆域边界数据不是直接显示再网页原码里的。通过分析我发现鼠标点击疆域部分后疆域边界会画红线，我就发现Network里有一个WFS请求，通过使用这个请求的Request URL，获取到了一段gml代码数据，刚开始使用xpath爬取，但是标签规则好像和html不同，没法爬取我需要的数据，后来采用正则表达式来获取边界数据，但是发现数据中有多处相同的标签，最后使用两次正则表达式取出边界数据。总共要获取三个朝代边界，由于每个朝代的边界数据请求URL不同且没有规律，我就将四个URL放到一个数组里（明疆域有两段），多次调用爬虫函数生成四个文件。

# %% [markdown]
# &emsp;&emsp;对于项目核心的画边界部分，主要利用的工具是pycharm里面的folium模块，其中的map函数对整体的地图进行可视化，然后通过设置地图的location参数对长城的地理位置和明代的疆域进行地图上的可视化，可视化原理是先确定地图上的点的位置，将具体的位置的点一次与其相邻的点连接起来，实现方式是利用folium的PolyLine函数将每一个分段内的点结合起来形成边界或者路线。最后成果是生成一个保存在桌面上的HTML文件。

# %% [markdown]
# &emsp;&emsp;由于本项目所需要查看的HTML文件有多个，手动一个一个打开比较繁琐，故设计了一个基于PYQT5的可视化界面，通过在界面上设置几个按钮控件以及展示HTML的QWebEngineView控件实现简单的加载HTML文件的功能。

# %% [markdown]
# ### 5.2 项目不足

# %% [markdown]
# **1) 手动打点，过与笨拙，重复的工作量过大**

# %% [markdown]
# **2) 爬虫技术不足，爬取出的数据短时间内无法解密**

# %% [markdown]
# ### 5.3 改进策略

# %% [markdown]
# &emsp;&emsp;本项目的主要难点在于数据的获取，网上没有相应的数据获取途径，仅仅有一些图片展示，采用本项目中的实现方式太过繁琐，重复工作量大。组内讨论认为可以利用图片分析技术，将网络上的样例图片中的线段用Python分析出来，实现项目目标。其中可以分为两种情况，第一种情况是直接对样图进行处理，将样图中的线或边界直接进行提取然后在本项目的地图上进行简单的图片融合，以达到项目目标。第二种情况是通过分析样图中线或边界所处的位置，构造机器学习模型，识别和分析出线或边界所处坐标的经纬度形成表格，最后以读表格的方式生成精度更高的线或边界。

# %% [markdown]
# &emsp;&emsp;后期项目可以和数据库链接，将爬取出的数据直接存入数据库，再通过调用数据库完成地图打点绘线绘图

# %% [markdown]
# ## 6 参考文献

# %% [markdown]
# [1]何星亮.中国古代民族分类的特点与中华民族的形成[J].宗教信仰与民族文化,2018(01):12-23.
# <p>[2]徐焰. 西汉用什么打败了匈奴[N]. 解放军报,2017-05-24(007).
# <p>[3]孙嘉,段飞志.如何理解游牧民族和农耕民族的冲突[J].河北旅游职业学院学报,2016,21(01):93-94.
#     <p>[4]袁喆，严登华.1961-2010年中国400mm和800mm等雨量线时空变化〔J〕.水科学进展，2014（04）.
#         <p>[5]俞炜华，南文海.“400mm等雨量线”、长城与农耕游牧民族的分界线〔J〕.上海交通大学学报，2009（01）.
#             <p>[6]高向东,王新贤,朱蓓倩.基于“胡焕庸线”的中国少数民族人口分布及其变动[J].人口研究,2016,40(03):3-17.
#                 <p>[7]陈建林. 长城在历史上对民族的关系浅析[J]. 高考(综合版), 2012(11):120-120.
#                     <p>[8]汪高鑫.汉代的民族交往与民族融合[J].学习与探索,2013(01):139-146.
#                         <p>[9]黄今言.汉朝与边境少数民族的关市贸易[J].中国社会经济史研究,1999(04):7-16.
#                             <p>[10]邓舒.唐朝民族管理的思想理念透视[J].贵州民族研究,2017,38(05):197-200.
#                               <p>[11]李万晖,唐建尧.浅谈唐朝时期的民族观念[J].才智,2012(13):162.
#                                   <p>[12]张飞翔.简述明朝的民族政策[J].开封教育学院学报,2016,36(08):3-4.
#
# <p>[13]金星. 明朝与蒙古的贸易研究[D].内蒙古大学,2012.
