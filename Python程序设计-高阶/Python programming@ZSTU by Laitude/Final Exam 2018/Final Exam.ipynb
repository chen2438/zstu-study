# %% [markdown]
# # Python考试题
# ## 说明
# - 所有考试题都是开放的，也就是说，并没有标准答案，你的得分完全是根据你<font color=red>**最终的方法、努力的过程、提交的程序和报告**</font>来决定。
# - 题号后面的★代表了题目的难度，最低★，最高★★★★★，最终得分会考虑题的难度。
# - 如果对应的题目有数据文件，则以题号相同名称的文件都为该题的数据文件，例：4.png，4.rar都是4号题的数据文件。
# - <font color=red>**每一题只能一个小组做，所以注册前，请务必确认该题没有被占用，并截图发到Python通知群**。</font>
# - <font color=red>**注册必须以小组注册，至少3人，不多于5人，否则注册无效**。</font>
# - 既然是由小组团队完成，你们的报告应该尽可能详细地描述你们的思想，你们的技术路线，你们的最终结果。简单地讲，就是你们做了什么，怎么做的，结果如何。
# - 希望你们的答辩选手能够很好地掌握你们做的内容，做得好，还要说得好。<br>
#
# **答辩事项：**
# 1. 答辩顺序为出题顺序；
# 2. 答辩自第17周三1、2节开始，之后的时间视情况而定，但在学期结束前全部结束；
# 3. 答辩人在答辩前随机抽签决定；
# 4. 提交内容：notebook文件和pdf文件（notebook文件的打印稿）各一份，包括：
#   - 必备信息：题目，团队名称，团队组成人员名单（包含学号）；
#   - 技术思路和解决方案（包含代码）；
#  - 运行结果；
#  - 自我评价，哪些地方做得好，哪些不行，要改进。
#  - 文件内容要求图文并茂。
# 5. 成绩评定：以最终答辩和提交的报告作为评价依据，给答辩人评分，<font color=red>**小组总分为答辩人评分乘以小组人数，各成员的分数在小组内自行分配**</font>。
#
#
#
# ##  <font color=red>**以下内容不允许编辑**。</font>
# 1	王贵平	陈影柔	吴鑫	林航	唐锦涛<br>
# 2	武文静	姜惠文	孙远昭		<br>
# 3	余泓锷	黄欣悦	郭仲 王明凯 王宇舟<br>
# 4	黄少捷	李星灿	许登 李想		<br>
# 5	张雪容	季玉文	杨海东		<br>
# 6	余建彩 蔡诚鑫 彭书海 李明 李瀚洋<br>
# 7	彭彦铮	王硕	赵恪振	姜丰怡	梁晨<br>
# 8	陈柄翰、蔡乐圆、叶欢、王宣凯		<br>
# 9	吴伟杰	任富彬	冯嘉东	杜尊仲	<br>
# 10	李巍岷	周彬馨	徐倩慧	洪骁涛 施旭辉	<br>
# 11	陈宏安	郭庆刚	何志杨		<br>
# 12	李彩娟	徐青怡	杨静	王耀宗	张硕<br>
# 13	林嘉豪	葛林焱	魏敏	莫怡超	<br>
# 14	崔哲豪	刘刚杰	温兴森		<br>
# 15 李建鹏、张逸恺、林志坤、黎子维、钱柱<br>
# 16 赵永康，陈中山，王博，王之浩<br>
# 17 王仕琪、古强、张飞达、陶昱松、刘琦<br>
# 18 马丽娜，何飞，王宁，康宇哲，王思敏<br>
# 19 李航橙，吴永昌，宋亚如<br>
# 20 王阔 韩明辰 田学芹<br>
# 21 陈哲 李乾坤 李欣洋 邓林汈<br>
# 22 朱凯 江玲叶 李岱岩<br>
# 23 项梦梵、阮昊青、杨天庸<br>
# 24 16张绍威 16罗昌文 16杨隆安 16余清达 16潘云露<br>
# 25 16李敬贤 16熊嘉诚 16孙铭江 16王永健 17费浩夫<br>
# 26 吴俚达 葛华盛 叶凯凯<br>
# 27 金子添 王佳凯 邵衢进 李晋峰 沈洋<br>
# 28 朱崎 何永威 葛宇航 方之成<br>
# 29 李雅静，缪佳惠，韦龙雨，吴鑫<br>
# 30 朱文轩 杨超 陈金华 陈路凯<br>
# 31 鲍晨翔、冯慧慧、刘凡、王旭、王文静<br>
# 32 陈学远 陈一霖 武帅<br>
# 33 陈宣宇、付前程、高超飞<br>
# 34 邵旸珂 贝史涛 周煜华<br>
# 35 邵旸珂 贝史涛 周煜华<br>
# 36 郑玉梅 朱小艳 高宗继 白紫嘉<br>
# 37 郭丁玮 吴正波 罗伊尹 庄英杰 王宇展<br>
# 38 周海梅 何学轩 熊慧香<br>
# 39 葛华盛、吴俚达、叶凯凯<br>
# 40 陈英健，陈童，罗斌，贾俊虎<br>
# 41 田涛 宣畅 曾泽华 孙文轩 童毅康<br>
# 42 莫林浩 周煜 顾尔波 张伟<br>
# 43 <br>

# %% [markdown]
# ## 1.豆瓣爬虫★★★
# - 请你在豆瓣上爬取关于影视的相关信息，内容包括：片名，上映时间，演员，评论及数量等；保存到一个数据库中。
# - 然后自己定义一个评价体系，按这个评价体系，对你爬取到的电影数据进行分类、排序和评价。
# - 将你的分类、排序、评价以一种可视化的方式展示出来（如可以使用matplotlib）。
# - 这里是队的注册：王贵平 陈影柔 吴鑫 林航 唐锦涛

# %% [markdown]
# ## 2. 网页表格转换为pdf★★★
# - 将任意一个网页表格的Html代码，转换为Latex的表格脚本，并生成一个Latex文件
# - 调用CCTex，将Latex文件转换为一个pdf文件。
# - 需要考虑复杂的表格。
# - 这里是队的注册：16武文静、16姜惠文、16孙远昭

# %% [markdown]
# ## 3. 文本转换为pdf★★★
# - 将一个文本文件，转换为Latex一个Latex文件。
# - 调用CCTex，将Latex文件转换为一个pdf文件。
# - 文本文件内容应该包括自己定义的一些格式或标识，转换后特定的格式如3.pdf所示，原来的内容如3.doc所示。
# - 可以不考虑表格、公式，如果能够考虑，本题可以变为★★★★★
# - 这里是队的注册：16王明凯、16郭仲、16黄欣悦、16余泓锷、16王宇舟

# %% [markdown]
# ## 4. 水体数据可视化展示★★★★
# - 将一系列水质仪检测到的水体数据，结合百度地图，将水体数据以可视化的形式进行展示。
# - 展示的图包括平面图和断面图等,以下是一个例子。
# <img src='4.png' width=300 height=200>
# - 这里是队的注册：黄少捷 李星灿 许登 李想

# %% [markdown]
# ## 5. Tornado地图服务★★★
# - 使用Tornado构建一个Web服务，根据前面页面输入的经度纬度坐标，调用百度地图服务，截取特定大小的地图，以图片的形式返回给前端。
# - 建立一个前端页面，输入经度、纬度、图片的高度、宽度，调用后端服务后，将返回的图片显示在该页面上。
# - 这里是队的注册：张雪容、季玉文、杨海东

# %% [markdown]
# ## 6. 曲线曲面造型★★★★
# - 给定几个平面上点的坐标，画出过这几个点的样条曲线，和以这几个点为控制点的贝赛尔曲线。
# - 给定空间内若干个点的坐标，画出过这几个点的曲面，曲面方程由你自己定义。
# - 这里是队的注册：余建彩 蔡诚鑫 彭书海 李明 李瀚洋

# %% [markdown]
# ## 7. 图片重叠处理★★★
# - 给定若干个图片，将这些图片以层叠的方式进行展示，以下是一个例子。
# <img src='7.png' width=100 height=150>
# - 使用的图片由你自己指定，显示的角度这些，自行指定，关键是显示效果。
# - 这里是队的注册：彭彦铮  ，王硕   ，赵恪振   ，姜丰怡   ，梁晨

# %% [markdown]
# ## 8. 标准和GDP可视化分析★★★
# - 参考给出的爬虫例子，爬取标准服务网上的国家、行业标准。
# - 爬取国家有关GDP数据（网站自己找）。
# - 对标准数量和GDP数量之间的关系进行可视化分析，研究它们之间的相关性。
# - 这里是队的注册：陈柄翰、蔡乐圆、叶欢、王宣凯

# %% [markdown]
# # 9. GeeTest破解★★★★★
# - 无论你用什么方法，使用Python破解GeeTest的一种认证形式（如下图）。
# <img src='9.png'>
# - 自己找一个网站，使用GeeTest认证的，来验证你的方法。
# - 视你实现的效果给分。
# - 这里是队的注册：无人东渡小组：（吴伟杰，任富彬，冯嘉东，杜尊仲）<br>

# %% [markdown]
# ## 10. 货币政策分析★★★
# - M0、M1、M2分别对应流通货币、狭义货币和广义货币，它们数量对于一个国家的经济非常重要。
# - 请你用爬虫爬取尽可能多的我国M0、M1、M2货币及GDP等相关经济数据。
# - 对你爬取到的数据，使用matplotlib或其他库进行可视化数据分析，然后再诠释你的数据分析结果，最好能够给出对经济数据的一些分析结论。
# - 这里是队的注册：李巍岷 周彬馨 徐倩慧 洪晓涛 施旭辉

# %% [markdown]
# ## 11. 程序员招聘★★★
# - 我们中的很多人，以后都要做程序员，那让我们来看一下现在程序员的需求情况。
# - 请你用爬虫爬取任何一个或多个招聘网站中，对程序员的招聘信息。
# - 对你爬取到的数据，使用matplotlib或其他库进行可视化数据分析，然后再诠释你的数据分析结果，看看目前哪种语言的程序员最热门。
# - 这里是队的注册：陈宏安 郭庆刚 何志扬

# %% [markdown]
# ## 12. 商品数据分析★★★
# - 电子商务越来越成为我们生活中不可或缺的一部分。
# - 请你用爬虫爬取任何一个电子商务网站，如京东、淘宝、苏宁等，中的某一类商品数据。
# - 对你爬取到的数据，你自己提出一些需求，然后根据这些需要分析这些数据，得到相关的结论。
# - 这里是队的注册：李彩娟 徐青怡 杨静 张硕 王耀宗

# %% [markdown]
# ## 13. 微信日程提醒★★★
# - 知道Server酱吗？
# - 请你利用Server酱，实现一个微信的日程提醒功能，能够实现你定义的一个日程提醒，即：在特定的时间，发一个微信消息给你，提醒你要干什么。
# - 自己定义详细的需求，根据你的需求来实现相应的功能。
# - 这里是队的注册：林嘉豪、葛林焱、莫怡超、魏敏

# %% [markdown]
# ## 14. 一门新语言★★★★
# - 现在请你来自己构造一门解释型的语言。
# - 利用Python实现一门语言的解释器，它能够识别你的语言的程序，实现相应的功能。
# - 实现功能可以有：输入输出，文件读写等，具体由你自己定义。
# - 这里是队的注册：崔哲豪、刘刚杰、温兴森

# %% [markdown]
# ## 15.基于Notebook的试题库★★★★
# - 现在让你做一个基于Notebook的试题库。
# - Notebook的每一节（就像本页的每一道题）都是一道题，内容包含：课程名，知识点，题目，分值和答案。
# - Python程序的输入是一个Notebook文件及相关附件所在目录，因为题目可能包含图片，Python自动把这些内容保存在数据库中。
# - Python程序的输出是一个Word或Pdf文件，内容是一张试卷，试卷的题目是从数据库中选择的，试卷中的每一题，最前面是一个二维码，这个二维码的内容包含了课程名称、知识点和分值。
# - 试卷的版面，由你自己设定，尽可能美观。
# - 这里是队的注册：李建鹏、张逸恺、林志坤、黎子维、钱柱

# %% [markdown]
# ## 16.二维码识别★★★
# - 现在请你用Python编程实现二维码的识别。
# - 在一个二值或灰度或彩色图像文件中，有多个二维码，请你全部识别出来。
# - 允许使用第三方库。
# - 本题最终的成绩是识别15题打印的扫描图片，对课程、题型、分数进行统计，识别的图像类型越多，识别率越高，分数越高。
# - 如果15题未能作出结果，请你自己生成若干类似文件，扫描后，进行识别。
# - 这里是队的注册：赵永康，陈中山，王博，王之浩

# %% [markdown]
# ## 17.空间闭包★★★★★
# - 三维空间内有若干个点，画出这些点的最小闭包。
# - 这个闭包最好是曲面围合的。
# - 给定一个与任意一个座标轴垂直的平面$\alpha$，能够显示$\alpha$与这个闭包的相交曲面。
# - 这里是队的注册：王仕琪、古强、张飞达、陶昱松、刘琦

# %% [markdown]
# ## 18.股票分析★★★★
# - 请你自选获取上证指数（或其他一些股票）的数据，将它们显示出来，类似于像股票软件的样子。
# - 对于你获取到的数据，请你用任何方法，对它们的走势进行一下预测，然后与真实的数据进行一个比较。
# - 希望你成为巴菲特第二。
# - 这里是队的注册：马丽娜 王宁 康宇哲 何飞 王思敏

# %% [markdown]
# ## 19.mp3播放器★★★★
# - 请你编写一个mp3播放器，能够播放mp3音乐，当然，如果能够播放wma、wav等其他音频格式文件，那就更好。
# - 不仅如何，它还有能够播放在线音频的能力，或者说：你输入一个地址，它能够嗅探到在线音频的mp3地址，然后把它下载并播放。
# - 我是不是说得太清楚了？
# - 这里是队的注册：李航橙，吴永昌，宋亚如

# %% [markdown]
# ## 20.视频播放器★★★★
# - 请你编写一个视频播放器，能够播放常见的视频格式。
# - 不仅如此，它还有能够播放在线视频的能力。
# - 具体参考上题，我就不多说了<font size='10'>☺</font>。
# - 这里是队的注册：王阔 韩明辰 田学芹 陈怀霖

# %% [markdown]
# ## 21.作者鉴定★★★★
# - 现在我们的对象转向古代，一直有人认为《水浒传》的作者不是施耐庵，而是罗贯中。
# - 现在就请你对《水浒传》来做一个判定，看看和《三国演义》到底风格是否相近。
# - 鉴定方法由你自己来设计，当然，必须用Python来实现哦。
# - 看看最后你的结论是什么？
# - 这里是队的注册：陈哲 李乾坤 李欣洋 邓林汈

# %% [markdown]
# ## 22.数据传输★★★★
# - 用网络的数据传输很常见，现在请你设计一个不常见的数据传输。
# - 请你用Python写一个程序，这个程序运行在两台笔记本上，实现两台笔记本之间的数据传输。
# - 但是，这个数据传输是有条件的，不允许使用有线、无线网络，如Lan、WiFi、Buletooth、2.4G、GSM、3G、4G、5G等，都是不允许的，当然，通过USB建立所谓的串行连接，用1394或其他的总线建立连接也是不允许的。
# - 总之，在数据传输时，我会检验笔记本的所有连接，都应处于Disable状态。
# - 如果你成功了，恭喜你，不过，还没完，你还要评估这个连接的数据传输速率，看看你能够达到多少，这个可以通过传输一个1M的文件来测试。
# - 这里是队的注册：朱凯 江玲叶 李岱岩

# %% [markdown]
# ## 23.糖尿病患者判断★★★★
# - 现在请你来当医生了。
# - 23.zip是一个印地安人糖尿病数据及相关说明，请你仔细阅读里面的说明文件。
# - 现在请你用Python来编写一个机器学习程序，利用其中的90%数据进行学习，用10%的数据进行测试，让这个程序能够自动判断一位印地安人是否真的罹患糖尿病。
# - 希望你的准确率达到80%。
# - 这里是队的注册：16项梦梵、16阮昊青、16杨天庸

# %% [markdown]
# ## 24.P2P金融★★★
# - 今年是P2P金融大爆雷的一年，现在想请你来分析一下目前的形势。
# - 请你尽可能多地获取自2018年1月1日以来，爆雷的P2P金融项目，获取相关信息，包括但不一定限于：总金额，涉及人数，注册地点等。
# - 然后对上述数据进行可视化分析，比如按省进行分析等。
# - 有可能的话，结合CPI、PMI、房价等信息，综合进行分析，数据的来源，请你自力更生。
# - 这里是队的注册：16张绍威 16罗昌文 16杨隆安 16余清达 16潘云露

# %% [markdown]
# ## 25.无人机控制★★★★★
# - 无人机的表演你看过吧，现在请你做设计师了。
# <img src='25.jpg' width=640 height=324>
# - 现在有625架无人机，希望它们能够在空中组成若干个图案。
# - 假定无人机起飞前，停在地上组成一个25*25的方阵，每架无人机之间间隔1米。
# - 之后的控制就交给你了，你来确定它们显示什么图案，然后控制它们进行图案的转换，注意，不能让他们碰撞哦。
# - 这里是队的注册：16李敬贤 16熊嘉诚 16孙铭江 16王永健 17费浩夫

# %% [markdown]
# ## 26.云计算基础★★★★
# - 虚拟化是云计算的基础，虚拟化基础之上的自动化，才能够使这个基础真正实际运行起来。
# - 现在请你用python来实现这个自动化，利用PyVIx和PySphere来操作ESXi虚拟机，实现复制、克隆、开机等一系列管理的自动化。
# - 既然要能够实现管理，当然需要一个管理界面，这个UI如何实现，你可以用你拿手的任何语言。
# - 希望你能够成为云计算的开发人员。
# - 这里是队的注册：吴俚达 葛华盛 叶凯凯

# %% [markdown]
# ## 27.无障碍浏览★★★★★
# - 让我们计算机人士来关爱一下有障碍的人士，比如盲人。
# - 他们想浏览网页时，但是即看不见，你能用Python来帮助他们吗？
# - 由你自己来设定无障碍的目标，不要害怕这个目标有多么小，任何的创新都是从一个小小的idea起步的，尽力去做吧。
# - 希望你能够成为一个热心公益的计算机人士。我想，大家都会感谢你！
# - 这里是队的注册：金子添 王佳凯 邵衢进 李晋峰 沈洋

# %% [markdown]
# ## 28.全球航班★★★★
# - 让我们把视线转向天空，你知道当前有多少飞机在天上翱翔吗？
# - 抱歉，我不知道，但我想知道，能你帮我吗？
# <img src='28.jpg' width=320 height=240>
# - 请你用python设计一个程序，它能够实时显示当前地球上的所有航班的动态情况，并且希望你能够告诉，从这样的图中，能够得到什么样的信息。
# - 这里是队的注册：朱崎 何永威 葛宇航 方之成

# %% [markdown]
# ## 29.全球路由★★★
# - 当我们访问www.microsoft.com的时候，我们的数据包通过了哪些地方？
# - 现在，请你设计一个可视化工具，能够显示我们在访问一个网络时，通过了哪些地方，希望它能够在地图展示，就像下面的图一样。
# <img src='29.jpg' width=320 height=320>
# - 最好是使用全球的地图。
# - 这里是队的注册：李雅静，缪佳惠，韦龙雨，吴鑫

# %% [markdown]
# ## 30.通用图灵机★★★★★
# - 通用图灵机是这样的一种图灵机，把其他图灵机的定义作为它的输入，它就能够模拟其他图灵机的运行。
# - 关于图灵机的定义，可以参考《计算理论导引》，本题的附件。
# - 现在请你用Python设计一个通用图灵机，看看它能够通用到什么程度。
# - 作为练习，请你先写一个求一个素数的图灵机，然后看看它的定义是什么。
# - 此题很难哦，如果你能很好的解决，我给你满分<font size='10'>☺</font>。
# - 这里是队的注册：朱文轩 杨超 陈金华 陈路凯

# %% [markdown]
# ## 31. 保护森林★★★
# - 松材线虫病（松线虫病）又称松树萎蔫病。是松树的一种毁灭性流行病。在我国松褐天牛(Monochamusalternatus)是它的主要传媒昆虫。致病力强，寄主死亡速度快；传播快，且常常猝不及防；一旦发生，治理难度大。
# - 目前国内松线虫疫情形势严峻，但严峻到什么程度，希望你用Python能够告诉我们答案。
# - 这里是队的注册：鲍晨翔、冯慧慧、刘凡、王旭、王文静

# %% [markdown]
# ## 32.计算 $\pi$ ★★★★
# - 计算$\pi$是简单的，但计算100万位的$\pi$需要较多的时间。
# - 请你无论用什么方法，希望你能够在尽可能短的时间内，计算3200万位的$\pi$。在我的笔记本上，Super Pi的成绩是
# <img src='32.png'>
# - 如果你能够在答辩的时间内，完成计算，那么，祝贺你，你成功了！
# - 这里是队的注册：陈学远 陈一霖 武帅

# %% [markdown]
# ## 33. 电视剧推荐★★★★
# - 附件33.rar是SQL SERVER的数据库备份文件的压缩包，里面是28万多条电视剧点播数据。
# - 数据的格式如下图。
# <img src='33.png'>
# - 字段说明：opentime：点播时间的字符串，requesttime：请求时间，f1：用户标识1，f2：用户标识2，channel：频道，starttime:被点播节目的开始时间，endtime：被点播节目的结束时间，type：点播方式，playtime：点播时间（如果是回放的话），program：节目名称（每一个是一集电视剧）。
# - 现在请你做两件事：
#  1. 找到每一个节目的最热门的时间段，然后将这些时间段按热度从大到小排序。
#  2. 对所有的电视剧进行聚类分析，提出你的推荐策略；比方说，A喜欢《脱身》，看了《脱身》的人都喜欢《爱国者》，你就可以把《爱国者》推荐给A。
# - 这里是队的注册：陈宣宇、付前程、高超飞

# %% [markdown]
# ## 34.追星★★★★
# - 影星大家都喜欢，很多人还追星，对影星如数家珍，但对宅男宅女的程序猿怎么办？
# - 当然难不倒我们。我们可以用百度人脸识别来帮我们追星。
# - 要求如下：
#  1. 构造你自己的影星库；
#  2. 调用百度人脸识别API，对任意一个图片或视频中，出现的影星进行识别；如果能够显示这个影星的详细信息，那就更好了。
# - 希望你用技术来战胜那些知识比较low的追星族。
# - 这里是队的注册：邵旸珂  贝史涛  周煜华

# %% [markdown]
# ## 35.声音控制笔记本★★★★★
# - 懒惰是人类最大的天性。我现在不想用手，只想用嘴就能控制我的笔记本。你能帮我吗？
# - 我想实现这样的功能：
#  1. 用我的声音登录；
#  2. 用我的声音打开我要软件；
#  3. 用我的声音来输入文字（比方说在Word中），调整格式；
#  4. 我想做任何事。
# - 我的要求是不是很高？套用一句沙宣的广告语：要求虽高，但终于找到。
# - 这里是队的注册：邵旸珂 贝史涛 周煜华
# PS： 没有看错，我们34  35都要，请同学们不要抢，谢谢

# %% [markdown]
# ## 36.文本编辑器★★★
# - 用进sublime吗？希望你能够写一款单文件，但是高效、易用的文本编辑器，如果你用你自己的文本编辑器，来编写python，是多么有成就的一件事啊。
# - 文本编辑器最好能够做到以下几点：
#  - 多语言支持，比方说Python，C等；
#  - 语法高亮、自动补足，如果能够自动提示语法，已定义过的变量或函数，那就更好了；
#  - 至于界面，参考Sublime，或其他优秀的编辑器，只是外表，我们更注重内心。
# - 这里是队的注册： 郑玉梅 朱小艳 高宗继 白紫嘉

# %% [markdown]
# ## 37.电影评价★★★★★
# - 一本电影好还是不好，观众说了算。
# - 附件是IMDB数据集，包含来自互联网的50000条严重两极分化的评论，该数据被分为用于训练的25000条评论和用于测试的25000条评论，训练集和测试集都包含50%的正面评价和50%的负面评价。该数据集已经经过预处理：评论（单词序列）已经被转换为整数序列，其中每个整数代表字典中的某个单词。
# - 现在，请你使用这个数据集，使用TensorFlow来构造一个机器学习模型，自动根据评论对电影进行评价。
# - 用测试集的结果来验证你的模型。
# - 这里是队的注册： 郭丁玮 吴正波 罗伊尹 庄英杰 王宇展

# %% [markdown]
# ## 38.图像水印★★★★
# - 图像水印和纸币的水印有相似之处，可以把你的一些版权信息嵌入在图像中，但是人的肉眼却不能查觉。
# - 好的图像水印能够抵抗对图像进行很多类型的操作，比方说裁剪、旋转、放大、缩小。
# - 一个公司花重金请了名设计师设计了一张设计图，但又怕人侵权，所以想把他们的Logo以某种形式嵌入在图形里，这样，图片就有了版权信息。注意，这个水印是看不到的，需要你运行一个工具才能提取出来的。
# <center><img src='38.png'>这是logo</center>
# - 你被选中来执行这个任务，希望你能够成功。设计图由你自己指定，分辨率、格式不限，Logo嵌入的方法不限。
# - 这里是队的注册：周海梅 何学轩 熊慧香

# %% [markdown]
# ## 39.弹道计算★★★★★
# - 我们国家和平了太久了，但事实上，战争的阴影一直就没有远离过，所以，我们要事先做点准备。
# - 战争时代，是放不下一张平静的书桌的，那个时候，可能我们学校就是一个前线基地。
# - 现在，请你计算，以我们学校为起点，关岛美军基地或其他美军基地为目标，发射弹道导弹的话，弹道应该是什么样子的？
# - 弹道满足的条件：
#  1. 弹道尽可能短；
#  2. 要穿越大气层。
# - 如果以图形化的方式给出结果，则更好。
# - 这里是队的注册：葛华盛、吴俚达、叶凯凯

# %% [markdown]
# ## 40.疫情控制★★★★★
# - 杭州市有许多个预防接种点。现在，突发疫情，需要将一批疫苗紧急配送到各个接种点，需要你的帮助。
# - 你的任务是：
#  1. 起点就是我们学校，规划运送车的路径，尽可能在短的时间内将所有的疫苗送到所有接种点。
#  2. 给出车辆的数量和所需要的时间。
#  3. 给出每一辆车的路线。
#  4. 如果能够考虑当前的交通状况，那就更完美了。
# - 这里是队的注册：罗斌 陈童 贾俊虎 陈英健

# %% [markdown]
# ## 41.区块链★★★★★
# - 数字货币一直希望能够替代传统货币，区块链是电子货币的基石。
# - 现在，请你用Python来设计一个区块链，并能够模拟区块链的各种业务逻辑。
# - 你要解决的一个很重要的问题是：怎么样来展示你的区域链，比如如果受到攻击了，或者有人试图欺诈，区块链是如何保护参与者的。
# - 这里是队的注册：田涛 宣畅 曾泽华 孙文轩 童毅康

# %% [markdown]
# ## 42.美军基地★★★
# - 美军在全球有基地，用以支撑它的全球霸权。
# - 下面请你做这样两件事：
#  1. 在全球地图上显示所有的美军基地；
#  2. 计算每个基地到我们学校的直线距离；
#  3. 根据基地的分布情况，分析原因。
# - 这里是队的注册：莫林浩  周煜 顾尔波 张伟

# %% [markdown]
# # 43.进程编辑器★★★★
# - 现在请你写一个Windwos进程编辑器，它具有如下功能：
#  1. 能够列举目前所有的正在运行的进程；
#  2. 能够找到Windows程序窗体的句柄，然后判断这个宋体的类型，对这个窗体进行相关的操作：包括Enable/Disable，输入文字，显示/隐藏等，获取窗体的文本等；
#  3. 能够对整个进程进行操作，如关闭。
# - 当然，它需要有个界面。
# - 这里是队的注册：
