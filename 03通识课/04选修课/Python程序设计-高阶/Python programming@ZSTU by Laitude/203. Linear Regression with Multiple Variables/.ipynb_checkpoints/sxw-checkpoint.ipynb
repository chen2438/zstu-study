# %%
# %matplotlib notebook

import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

#read data file
df=pd.read_csv("data/boston.csv", header=0)
#show data digest information
print(df.describe())
# Out:
#              CRIM         ZN       INDUS         CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
#get df value
df=df.values

#change df into np arraystyle
df=np.array(df)

#x_data 前面12列的特征数据
x_data=df[:,:12]
#y_data 前面12列的特征数据
y_data=df[:,12]

# %%
#12个特征占位符
x=tf.placeholder(tf.float32,[None,12],name="X")
#1个标签占位符
y=tf.placeholder(tf.float32,[None,1],name="Y")

# %%
#定义命名空间
with tf.name_scope("Model"):
    #初始化值为shape=（12,1）的随机数
    w=tf.Variable(tf.random_normal([12,1],stddev=0.01),name="W")
    #初始化b为1.0
    b=tf.Variable(1.0,name="b")
    
    def model(x,w,b):
        return tf.matmul(x,w)+b
    
    pred=model(x,w,b)

# %%
train_epochs=50
learning_rate=0.01

# %%
#定义损失函数
with tf.name_scope("LossFunction"):
    loss_function=tf.reduce_mean(tf.pow(y-pred,2))

# %%
optimizer=tf.train.GradientDescentOptimizer(learning_rate).minimize(loss_function)

# %%
sess=tf.Session()
init=tf.global_variables_initializer()

sess.run(init)

# %%
for epoch in range(train_epochs):
    loss_sum=0.0
    for xs,ys in zip(x_data,y_data):
        xs=xs.reshape(1,12)
        ys=ys.reshape(1,1)
        
        _, loss=sess.run([optimizer,loss_function],feed_dict={x:xs,y:ys})
        loss_sum=loss_sum+loss
       
    
    #打乱数据顺序
    x_data,y_data=shuffle(x_data,y_data)
    
    b0temp=b.eval(session=sess)
    w0temp=w.eval(session=sess)
    loss_average=loss_sum/len(y_data)
    print(loss_average, b0temp, w0temp)
    
    plt.plot("epoch=",epoch+1, "loss=", loss_average, "b=",b0temp,"w=",w0temp)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f64bf0572a86> in <module>()
#      16     loss_average=loss_sum/len(y_data)
#      17
# ---> 18     plt.plot("epoch=",epoch+1, "b=",b0temp,"w=",w0temp)
#
# C:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# C:\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
# ...

# %%
#对特征数据0到11列做归一化
for i in range(12):
    df[:,i]=(df[:,i]-df[:,i].min())/(df[:,i].max()-df[:,i].min())

# %%
x_data=df[:,:12]
y_data=df[:,1]

# %%
n=348
x_test=x_data[n]

x_test=x_test.reshape(1,12)
predict=sess.run(pred,feed_dict={x:x_test})
print("预测值:%f" %predict)

target=y_data[n]
print("标签值：%f" %target)

# %%
n=np.random.randint（506）
print(n)
x_test=x_data[n]

x_test=x_test.reshape(1,12)
predict=sess.run(pred,feed_dict={x:x_test})
print("预测值:%f" %predict)

target=y_data[n]
print("标签值：%f" %target)

# %%
loss_list=[]#用于保存loss值的列表

for epoch in range (train_epochs):
    loss_sum=0.0
    for xs,ys in zip(x_data,y_data):
        xs=xs.reshape(1,12)
        ys=ys.reshape(1,1)
        
        _, loss=sess.run([optimizer,loss_function],feed_dict={x:xs,y:ys})
        loss_sum=loss_sum+loss
    
    #打乱数据顺序
    x_data,y_data=shuffle(x_data,y_data)
    
    b0temp=b.eval(session=sess)
    w0temp=w.eval(session=sess)
    loss_average=loss_sum/len(y_data)
    
    loss_list.append(loss_average)#每轮添加一次
    
    plt.plot("epoch=",epoch+1,"loss=",loss_average, "b=",b0temp,"w=",w0temp)

    plt.plot(loss_list)

# %%
loss_list=[]#用于保存loss值的列表

for epoch in range (train_epochs):
    loss_sum=0.0
    for xs,ys in zip(x_data,y_data):
        xs=xs.reshape(1,12)
        ys=ys.reshape(1,1)
        
        _, loss=sess.run([optimizer,loss_function],feed_dict={x:xs,y:ys})
        loss_sum=loss_sum+loss
    
    #打乱数据顺序
    x_data,y_data=shuffle(x_data,y_data)
    
    b0temp=b.eval(session=sess)
    w0temp=w.eval(session=sess)
    loss_average=loss_sum/len(y_data)
    
    loss_list.append(loss)#每轮添加一次
    
    plt.plot("epoch=",epoch+1,"loss=",loss_average, "b=",b0temp,"w=",w0temp)

    plt.plot(loss_list)

# %%
sess=tf.Session()
init=tf.global_variable_initializer()

#设置日志存储目录
logdir='d:/log'

# %%
#创建一个操作，用于记录损失值loss，后再在Tensorboard中scalars栏可见
sum_loss_op=tf.summary.scalar("loss",loss_function)

#把所有需要记录摘要日志文件的合并，方便一次性写入
merged=tf.summary.merge_all()
